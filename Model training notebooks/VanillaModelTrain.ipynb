# %%
# !pip install  'tensorflow-text==2.8.*'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-text==2.8.*
#   Downloading tensorflow_text-2.8.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 4.7 MB/s
# Collecting tensorflow<2.9,>=2.8.0
#   Downloading tensorflow-2.8.3-cp37-cp37m-manylinux2010_x86_64.whl (497.9 MB)
#      |████████████████████████████████| 497.9 MB 34 kB/s
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text==2.8.*) (0.12.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.1.2)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.3.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.50.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (57.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.14.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (3.17.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (0.27.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (2.0.1)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (14.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (3.1.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (0.4.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.12)
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 51.0 MB/s
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.21.6)
# Collecting tensorflow-estimator<2.9,>=2.8
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 44.0 MB/s
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (4.1.1)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 45.0 MB/s
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (3.9.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.*) (3.2.2)
# Installing collected packages: tensorflow-estimator, tensorboard, keras, tensorflow, tensorflow-text
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
#     Uninstalling tensorflow-2.9.2:
#       Successfully uninstalled tensorflow-2.9.2
# Successfully installed keras-2.8.0 tensorboard-2.8.0 tensorflow-2.8.3 tensorflow-estimator-2.8.0 tensorflow-text-2.8.2

# %%
import tensorflow as tf
import tensorflow_text as text

# %%
import collections
import os
import pathlib
import re
import string
import sys
import tempfile
import time

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_text as text
import pandas as pd
import tensorflow_datasets as tfds
from sklearn.model_selection import train_test_split
import keras
import logging

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
model_name = 'spoc_pseudocode_to_code_converter'

tokenizers = tf.saved_model.load('drive/MyDrive/MajorProjectPseudoCodeCpp/Tokenizer')
print(tokenizers.prob.get_vocab_size().numpy())
print(tokenizers.sol.get_vocab_size().numpy())
# Out:
# 2201
# 1774

# %%
dataset = pd.read_csv("drive/MyDrive/MajorProjectPseudoCodeCpp/spoc_cleaned_next.csv")

# %%
train_examples = dataset[2000:]
val_examples = dataset[:2000]

# %%
def dataset_to_tensor(data_examples):
  data_prob = []
  for i in range(0,len(data_examples)):
    temp = str(data_examples.iloc[i,0])
    tempval = temp.replace('_',',')
    data_prob.append(tempval)

  # inputs = data_examples['problem']
  print(data_prob[0])
  print(type(data_prob))

  data_sol = []
  for i in range(0,len(data_examples)):
    temp = str(data_examples.iloc[i,1])
    tempval = temp.replace('_',',')
    data_sol.append(tempval)

  # inputs = data_examples['solution']
  print(data_sol[0])
  print(type(data_sol))

  tensor_prob = tf.convert_to_tensor(data_prob)
  tensor_sol = tf.convert_to_tensor(data_sol)

  tensor_data = tf.data.Dataset.from_tensor_slices((tensor_prob,tensor_sol))

  # tf.data.experimental.cardinality(tensor_data)
  return tensor_data, tensor_prob, tensor_sol;

# %%
val_data , prob_tensr, sol_tensr = dataset_to_tensor(val_examples)
train_data, train_p, train_s = dataset_to_tensor(train_examples)
# Out:
# if b=1 return a, else call function gcd(b, a%b)            n , nn, ans = integers with ans =0    Read n    for i=2 to n-1 execute    set nn to n    while nn is not equal to 0, set ans to ans + nn%i, and also set nn= nn/i        set o to gcd(ans, n-2)    print out ans/o "/" (n-2)/o            function gcd with integer arguments a and b    return !b ? a : gcd(b, a % b)            integers n, nn and ans = 0    read n    for i = 2 to n - 1 inclusive    set nn to n    while nn increment ans by (nn % i) and set nn to nn / i;        integer o = gcd of ans and n - 2    print ans / o, "/", (n - 2) / o and "\n"
# <class 'list'>
# return !b ? a : gcd(b, a % b);    }    int main() {    int n, nn, ans = 0;    cin >> n;    for (int i = 2; i <= n - 1; ++i) {    nn = n;    while (nn) ans += nn % i, nn /= i;    }    int o = gcd(ans, n - 2);    cout << ans / o << "/" << (n - 2) / o << "\n";    return 0;    }    int gcd(int a, int b) {    return !b ? a : gcd(b, a % b);    }    int main() {    int n, nn, ans = 0;    cin >> n;    for (int i = 2; i <= n - 1; ++i) {    nn = n;    while (nn) ans += nn % i, nn /= i;    }    int o = gcd(ans, n - 2);    cout << ans / o << "/" << (n - 2) / o << "\n";    return 0;    }
# <class 'list'>
# a = long long    m = map of int to int    for i = 0 to 4 exclusive    read a    increment m[a]        print 4 - m.size()
# <class 'list'>
# long long a;    map<int, int> m;    for (int i = 0; i < 4; i++) {    cin >> a;    m[a]++;    }    cout << 4 - m.size() << endl;    }
# <class 'list'>

# %%
MAX_TOKENS = 800

# %%
#  a function to drop the examples longer than MAX_TOKENS:
def filter_max_tokens(prob, sol):
  num_tokens = tf.maximum(tf.shape(prob)[1],tf.shape(sol)[1])
  return num_tokens < MAX_TOKENS

# %%
# a function that tokenizes the batches of raw text
def tokenize_pairs(prob, sol):
    prob = tokenizers.prob.tokenize(prob)
    # Convert from ragged to dense, padding with zeros.
    prob = prob.to_tensor()

    sol = tokenizers.sol.tokenize(sol)
    # Convert from ragged to dense, padding with zeros.
    sol = sol.to_tensor()
    return prob, sol

# %%
# input pipeline that processes, shuffles and batches the data

BUFFER_SIZE = 20000
BATCH_SIZE = 16

def make_batches(ds):
  return (
      ds
      .cache()
      .shuffle(BUFFER_SIZE)
      .batch(BATCH_SIZE)
      .map(tokenize_pairs, num_parallel_calls=tf.data.AUTOTUNE)
      .filter(filter_max_tokens)
      .prefetch(tf.data.AUTOTUNE))

# %%
train_batches = make_batches(train_data)

val_batches = make_batches(val_data)

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

def positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

  pos_encoding = angle_rads[np.newaxis, ...]

  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
n, d = 2048, 512
pos_encoding = positional_encoding(n, d)
print(pos_encoding.shape)
pos_encoding = pos_encoding[0]

# Juggle the dimensions for the plot
pos_encoding = tf.reshape(pos_encoding, (n, d//2, 2))
pos_encoding = tf.transpose(pos_encoding, (2, 1, 0))
pos_encoding = tf.reshape(pos_encoding, (d, n))

plt.pcolormesh(pos_encoding, cmap='RdBu')
plt.ylabel('Depth')
plt.xlabel('Position')
plt.colorbar()
plt.show()
# Out:
# (1, 2048, 512)

# %%
#Masking
# Mask all the pad tokens in the batch of sequence. 
# It ensures that the model does not treat padding as the input. 
# The mask indicates where pad value 0 is present:
#  it outputs a 1 at those locations, and a 0 otherwise.
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)

  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1

# %%
# The look-ahead mask is used to mask the future tokens in a sequence.
#  In other words, the mask indicates which entries should not be used.

# This means that to predict the third token, only the first and second token
#  will be used. Similarly to predict the fourth token, only the first,
#   second and the third tokens will be used and so on.

def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask  # (seq_len, seq_len)

# %%
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead)
  but it must be broadcastable for addition.

  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable
          to (..., seq_len_q, seq_len_k). Defaults to None.

  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

# %%
def print_out(q, k, v):
  temp_out, temp_attn = scaled_dot_product_attention(
      q, k, v, None)
  print('Attention weights are:')
  print(temp_attn)
  print('Output is:')
  print(temp_out)

# %%
# np.set_printoptions(suppress=True)

# temp_k = tf.constant([[10, 0, 0],
#                       [0, 10, 0],
#                       [0, 0, 10],
#                       [0, 0, 10]], dtype=tf.float32)  # (4, 3)

# temp_v = tf.constant([[1, 0],
#                       [10, 0],
#                       [100, 5],
#                       [1000, 6]], dtype=tf.float32)  # (4, 2)

# # This `query` aligns with the second `key`,
# # so the second `value` is returned.
# temp_q = tf.constant([[0, 10, 0]], dtype=tf.float32)  # (1, 3)
# print_out(temp_q, temp_k, temp_v)

# %%
class multiHeadAttention(keras.layers.Layer):
  def __init__(self,*, d_model, num_heads):
    super(multiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.wq = keras.layers.Dense(d_model)
    self.wk = keras.layers.Dense(d_model)
    self.wv = keras.layers.Dense(d_model)

    self.dense = keras.layers.Dense(d_model)

  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])

  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]

    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)

    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

    return output, attention_weights

# %%
# temp_mha = multiHeadAttention(d_model=512, num_heads=8)
# y = tf.random.uniform((1, 60, 512))  # (batch_size, encoder_sequence, d_model)
# out, attn = temp_mha(y, k=y, q=y, mask=None)
# out.shape, attn.shape

# %%
def point_wise_feed_forward_network(d_model, dff):
  return keras.Sequential([
      keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %%
# sample_ffn = point_wise_feed_forward_network(512, 2048)
# sample_ffn(tf.random.uniform((64, 50, 512))).shape

# %%
class EncoderLayer(keras.layers.Layer):
  def __init__(self,*, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = multiHeadAttention(d_model=d_model, num_heads=num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = keras.layers.Dropout(rate)
    self.dropout2 = keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)

    return out2

# %%
# sample_encoder_layer = EncoderLayer(d_model=512, num_heads=8, dff=2048)

# sample_encoder_layer_output = sample_encoder_layer(
#     tf.random.uniform((64, 43, 512)), False, None)

# sample_encoder_layer_output.shape  # (batch_size, input_seq_len, d_model)

# %%
class DecoderLayer(keras.layers.Layer):
  def __init__(self,*, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = multiHeadAttention(d_model=d_model, num_heads=num_heads)
    self.mha2 = multiHeadAttention(d_model=d_model, num_heads=num_heads)

    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = keras.layers.Dropout(rate)
    self.dropout2 = keras.layers.Dropout(rate)
    self.dropout3 = keras.layers.Dropout(rate)

  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):
    # enc_output.shape == (batch_size, input_seq_len, d_model)

    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)

    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

    ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

    return out3, attn_weights_block1, attn_weights_block2

# %%
# sample_decoder_layer = DecoderLayer(d_model=512, num_heads=8, dff=2048)

# sample_decoder_layer_output, _, _ = sample_decoder_layer(
#     tf.random.uniform((64, 50, 512)), sample_encoder_layer_output,
#     False, None, None)

# sample_decoder_layer_output.shape  # (batch_size, target_seq_len, d_model)

# %%
#encoder consists of input embedding , positional encoding and n encoder layers

class Encoder(keras.layers.Layer):
  def __init__(self,*, num_layers, d_model, num_heads, dff, input_vocab_size,
               rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(MAX_TOKENS, self.d_model)

    self.enc_layers = [
        EncoderLayer(d_model=d_model, num_heads=num_heads, dff=dff, rate=rate)
        for _ in range(num_layers)]

    self.dropout = keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    seq_len = tf.shape(x)[1]

    # adding embedding and position encoding.
    x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)

    return x  # (batch_size, input_seq_len, d_model)

# %%
# sample_encoder = Encoder(num_layers=2, d_model=512, num_heads=8,
#                          dff=2048, input_vocab_size=8500)
# temp_input = tf.random.uniform((64, 62), dtype=tf.int64, minval=0, maxval=200)

# sample_encoder_output = sample_encoder(temp_input, training=False, mask=None)

# print(sample_encoder_output.shape)  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(keras.layers.Layer):
  def __init__(self,*, num_layers, d_model, num_heads, dff, target_vocab_size,
               rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(MAX_TOKENS, d_model)

    self.dec_layers = [
        DecoderLayer(d_model=d_model, num_heads=num_heads, dff=dff, rate=rate)
        for _ in range(num_layers)]
    self.dropout = keras.layers.Dropout(rate)

  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):

    seq_len = tf.shape(x)[1]
    attention_weights = {}

    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)

      attention_weights[f'decoder_layer{i+1}_block1'] = block1
      attention_weights[f'decoder_layer{i+1}_block2'] = block2

    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %%
# sample_decoder = Decoder(num_layers=2, d_model=512, num_heads=8,
#                          dff=2048, target_vocab_size=8000)
# temp_input = tf.random.uniform((64, 26), dtype=tf.int64, minval=0, maxval=200)

# output, attn = sample_decoder(temp_input,
#                               enc_output=sample_encoder_output,
#                               training=False,
#                               look_ahead_mask=None,
#                               padding_mask=None)

# output.shape, attn['decoder_layer2_block2'].shape

# %%
class Transformer(keras.Model):
  def __init__(self,*, num_layers, d_model, num_heads, dff, input_vocab_size,
               target_vocab_size, rate=0.1):
    super().__init__()
    self.encoder = Encoder(num_layers=num_layers, d_model=d_model,
                           num_heads=num_heads, dff=dff,
                           input_vocab_size=input_vocab_size, rate=rate)

    self.decoder = Decoder(num_layers=num_layers, d_model=d_model,
                           num_heads=num_heads, dff=dff,
                           target_vocab_size=target_vocab_size, rate=rate)

    self.final_layer = keras.layers.Dense(target_vocab_size)

  def call(self, inputs, training):
    # Keras models prefer if you pass all your inputs in the first argument
    inp, tar = inputs

    padding_mask, look_ahead_mask = self.create_masks(inp, tar)

    enc_output = self.encoder(inp, training, padding_mask)  # (batch_size, inp_seq_len, d_model)

    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, padding_mask)

    final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)

    return final_output, attention_weights

  def create_masks(self, inp, tar):
    # Encoder padding mask (Used in the 2nd attention block in the decoder too.)
    padding_mask = create_padding_mask(inp)

    # Used in the 1st attention block in the decoder.
    # It is used to pad and mask future tokens in the input received by
    # the decoder.
    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = create_padding_mask(tar)
    look_ahead_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return padding_mask, look_ahead_mask

# %%
# sample_transformer = Transformer(
#     num_layers=2, d_model=512, num_heads=8, dff=2048,
#     input_vocab_size=8500, target_vocab_size=8000)

# temp_input = tf.random.uniform((64, 38), dtype=tf.int64, minval=0, maxval=200)
# temp_target = tf.random.uniform((64, 36), dtype=tf.int64, minval=0, maxval=200)

# fn_out, _ = sample_transformer([temp_input, temp_target], training=False)

# fn_out.shape  # (batch_size, tar_seq_len, target_vocab_size)

# %%
# hyperparameters
num_layers = 4
d_model = 128
dff = 512
num_heads = 8
dropout_rate = 0.1

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                     epsilon=1e-3)

# %%
temp_learning_rate_schedule = CustomSchedule(d_model)

plt.plot(temp_learning_rate_schedule(tf.range(40000, dtype=tf.float32)))
plt.ylabel('Learning Rate')
plt.xlabel('Train Step')
# Out:
# Text(0.5, 0, 'Train Step')

# %%
loss_object = keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)


def accuracy_function(real, pred):
  accuracies = tf.equal(real, tf.argmax(pred, axis=2))

  mask = tf.math.logical_not(tf.math.equal(real, 0))
  accuracies = tf.math.logical_and(mask, accuracies)

  accuracies = tf.cast(accuracies, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_loss = keras.metrics.Mean(name='train_loss')
train_accuracy = keras.metrics.Mean(name='train_accuracy')
validation_loss = keras.metrics.Mean(name='validation_loss')
validation_accuracy = keras.metrics.Mean(name='validation_accuracy')

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=tokenizers.prob.get_vocab_size().numpy(),
    target_vocab_size=tokenizers.sol.get_vocab_size().numpy(),
    rate=dropout_rate)

# %%
EPOCHS = 100

# %%
# The @tf.function trace-compiles train_step into a TF graph for faster
# execution. The function specializes to the precise shape of the argument
# tensors. To avoid re-tracing due to the variable sequence lengths or variable
# batch sizes (the last batch is smaller), use input_signature to specify
# more generic shapes.

train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]


@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]

  with tf.GradientTape() as tape:
    predictions, _ = transformer([inp, tar_inp],
                                 training = True)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

  train_loss(loss)
  train_accuracy(accuracy_function(tar_real, predictions))

# %%
# from tensorflow.python.ops.numpy_ops import np_config
# np_config.enable_numpy_behavior()

val_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]


@tf.function(input_signature=val_step_signature)
def val_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]

  with tf.GradientTape() as tape:
    predictions, _ = transformer([inp, tar_inp],
                                 training = False)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

  validation_loss(loss)
  validation_accuracy(accuracy_function(tar_real, predictions))

# %%
e_list =[]
acc_list = []
loss_list = []
val_acc_list = []
val_loss_list = []
for epoch in range(EPOCHS):
  start = time.time()

  train_loss.reset_states()
  train_accuracy.reset_states()

  # inp -> problem pseudocode, tar -> solution in c++
  for (batch, (inp, tar)) in enumerate(train_batches):
    train_step(inp, tar)

    if batch % 50 == 0:
      print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

#   if (epoch + 1) % 5 == 0:
#     # ckpt_save_path = ckpt_manager.save()
#     print(f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')

  print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')
  e_list.append(epoch+1)
  loss_list.append(train_loss.result())
  acc_list.append(train_accuracy.result())
  print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')

  validation_loss.reset_states()
  validation_accuracy.reset_states()
  start = time.time()
  # inp -> problem pseudocode, tar -> solution in c++
  for (batch, (inp, tar)) in enumerate(val_batches):
    val_step(inp, tar)


  print(f'Epoch {epoch + 1} Loss {validation_loss.result():.4f} Accuracy {validation_accuracy.result():.4f}')
  
  val_loss_list.append(validation_loss.result())
  val_acc_list.append(validation_accuracy.result())
  print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 1.0501 Accuracy 0.7109
# Epoch 1 Batch 50 Loss 1.0508 Accuracy 0.7203
# Epoch 1 Batch 100 Loss 1.0310 Accuracy 0.7240
# Epoch 1 Batch 150 Loss 1.0372 Accuracy 0.7231
# Epoch 1 Batch 200 Loss 1.0394 Accuracy 0.7232
# Epoch 1 Batch 250 Loss 1.0396 Accuracy 0.7236
# Epoch 1 Batch 300 Loss 1.0439 Accuracy 0.7226
# Epoch 1 Batch 350 Loss 1.0404 Accuracy 0.7228
# Epoch 1 Batch 400 Loss 1.0348 Accuracy 0.7241
# Epoch 1 Batch 450 Loss 1.0337 Accuracy 0.7244
# Epoch 1 Batch 500 Loss 1.0308 Accuracy 0.7252
# Epoch 1 Batch 550 Loss 1.0286 Accuracy 0.7255
# Epoch 1 Batch 600 Loss 1.0297 Accuracy 0.7252
# Epoch 1 Batch 650 Loss 1.0282 Accuracy 0.7256
# Epoch 1 Batch 700 Loss 1.0275 Accuracy 0.7257
# Epoch 1 Batch 750 Loss 1.0272 Accuracy 0.7257
# Epoch 1 Loss 1.0270 Accuracy 0.7256
# Time taken for 1 epoch: 127.64 secs
#
# Epoch 1 Loss 0.9776 Accuracy 0.7375
# Time taken for 1 epoch: 24.64 secs
#
# Epoch 2 Batch 0 Loss 0.8887 Accuracy 0.7381
# Epoch 2 Batch 50 Loss 0.9818 Accuracy 0.7293
# Epoch 2 Batch 100 Loss 0.9875 Accuracy 0.7299
# Epoch 2 Batch 150 Loss 0.9845 Accuracy 0.7317
# Epoch 2 Batch 200 Loss 0.9826 Accuracy 0.7327
# Epoch 2 Batch 250 Loss 0.9830 Accuracy 0.7322
# Epoch 2 Batch 300 Loss 0.9819 Accuracy 0.7324
# Epoch 2 Batch 350 Loss 0.9828 Accuracy 0.7323
# Epoch 2 Batch 400 Loss 0.9870 Accuracy 0.7318
# Epoch 2 Batch 450 Loss 0.9838 Accuracy 0.7326
# Epoch 2 Batch 500 Loss 0.9831 Accuracy 0.7331
# Epoch 2 Batch 550 Loss 0.9857 Accuracy 0.7328
# Epoch 2 Batch 600 Loss 0.9873 Accuracy 0.7327
# Epoch 2 Batch 650 Loss 0.9865 Accuracy 0.7330
# Epoch 2 Batch 700 Loss 0.9854 Accuracy 0.7331
# Epoch 2 Batch 750 Loss 0.9852 Accuracy 0.7332
# Epoch 2 Loss 0.9858 Accuracy 0.7332
# Time taken for 1 epoch: 122.78 secs
#
# Epoch 2 Loss 0.9332 Accuracy 0.7452
# Time taken for 1 epoch: 24.95 secs
#
# Epoch 3 Batch 0 Loss 0.8598 Accuracy 0.7647
# Epoch 3 Batch 50 Loss 0.9503 Accuracy 0.7415
# Epoch 3 Batch 100 Loss 0.9534 Accuracy 0.7411
# Epoch 3 Batch 150 Loss 0.9519 Accuracy 0.7406
# Epoch 3 Batch 200 Loss 0.9481 Accuracy 0.7411
# Epoch 3 Batch 250 Loss 0.9524 Accuracy 0.7405
# Epoch 3 Batch 300 Loss 0.9494 Accuracy 0.7413
# Epoch 3 Batch 350 Loss 0.9511 Accuracy 0.7407
# Epoch 3 Batch 400 Loss 0.9518 Accuracy 0.7403
# Epoch 3 Batch 450 Loss 0.9480 Accuracy 0.7410
# Epoch 3 Batch 500 Loss 0.9491 Accuracy 0.7406
# Epoch 3 Batch 550 Loss 0.9503 Accuracy 0.7404
# Epoch 3 Batch 600 Loss 0.9485 Accuracy 0.7407
# Epoch 3 Batch 650 Loss 0.9476 Accuracy 0.7410
# Epoch 3 Batch 700 Loss 0.9488 Accuracy 0.7405
# Epoch 3 Batch 750 Loss 0.9488 Accuracy 0.7405
# Epoch 3 Loss 0.9487 Accuracy 0.7406
# Time taken for 1 epoch: 123.74 secs
#
# Epoch 3 Loss 0.8791 Accuracy 0.7562
# Time taken for 1 epoch: 23.29 secs
#
# Epoch 4 Batch 0 Loss 1.0176 Accuracy 0.7167
# Epoch 4 Batch 50 Loss 0.9175 Accuracy 0.7451
# Epoch 4 Batch 100 Loss 0.9053 Accuracy 0.7489
# Epoch 4 Batch 150 Loss 0.9098 Accuracy 0.7475
# Epoch 4 Batch 200 Loss 0.9133 Accuracy 0.7466
# Epoch 4 Batch 250 Loss 0.9151 Accuracy 0.7469
# Epoch 4 Batch 300 Loss 0.9169 Accuracy 0.7464
# Epoch 4 Batch 350 Loss 0.9177 Accuracy 0.7462
# Epoch 4 Batch 400 Loss 0.9182 Accuracy 0.7464
# Epoch 4 Batch 450 Loss 0.9178 Accuracy 0.7467
# Epoch 4 Batch 500 Loss 0.9189 Accuracy 0.7463
# Epoch 4 Batch 550 Loss 0.9192 Accuracy 0.7462
# Epoch 4 Batch 600 Loss 0.9189 Accuracy 0.7464
# Epoch 4 Batch 650 Loss 0.9187 Accuracy 0.7465
# Epoch 4 Batch 700 Loss 0.9170 Accuracy 0.7468
# Epoch 4 Batch 750 Loss 0.9175 Accuracy 0.7468
# Epoch 4 Loss 0.9178 Accuracy 0.7468
# Time taken for 1 epoch: 124.27 secs
#
# Epoch 4 Loss 0.8450 Accuracy 0.7645
# Time taken for 1 epoch: 25.38 secs
#
# Epoch 5 Batch 0 Loss 0.8308 Accuracy 0.7670
# Epoch 5 Batch 50 Loss 0.9205 Accuracy 0.7450
# Epoch 5 Batch 100 Loss 0.9098 Accuracy 0.7477
# Epoch 5 Batch 150 Loss 0.9023 Accuracy 0.7492
# Epoch 5 Batch 200 Loss 0.8953 Accuracy 0.7507
# Epoch 5 Batch 250 Loss 0.8940 Accuracy 0.7510
# Epoch 5 Batch 300 Loss 0.8966 Accuracy 0.7502
# Epoch 5 Batch 350 Loss 0.8987 Accuracy 0.7499
# Epoch 5 Batch 400 Loss 0.9012 Accuracy 0.7494
# Epoch 5 Batch 450 Loss 0.8966 Accuracy 0.7504
# Epoch 5 Batch 500 Loss 0.8972 Accuracy 0.7502
# Epoch 5 Batch 550 Loss 0.8940 Accuracy 0.7510
# Epoch 5 Batch 600 Loss 0.8931 Accuracy 0.7513
# Epoch 5 Batch 650 Loss 0.8928 Accuracy 0.7513
# Epoch 5 Batch 700 Loss 0.8927 Accuracy 0.7515
# Epoch 5 Batch 750 Loss 0.8907 Accuracy 0.7520
# Epoch 5 Loss 0.8902 Accuracy 0.7521
# Time taken for 1 epoch: 124.61 secs
#
# Epoch 5 Loss 0.8160 Accuracy 0.7704
# Time taken for 1 epoch: 23.85 secs
#
# Epoch 6 Batch 0 Loss 0.8863 Accuracy 0.7594
# Epoch 6 Batch 50 Loss 0.8594 Accuracy 0.7578
# Epoch 6 Batch 100 Loss 0.8742 Accuracy 0.7538
# Epoch 6 Batch 150 Loss 0.8720 Accuracy 0.7540
# Epoch 6 Batch 200 Loss 0.8708 Accuracy 0.7542
# Epoch 6 Batch 250 Loss 0.8660 Accuracy 0.7556
# Epoch 6 Batch 300 Loss 0.8619 Accuracy 0.7565
# Epoch 6 Batch 350 Loss 0.8604 Accuracy 0.7571
# Epoch 6 Batch 400 Loss 0.8642 Accuracy 0.7560
# Epoch 6 Batch 450 Loss 0.8645 Accuracy 0.7559
# Epoch 6 Batch 500 Loss 0.8621 Accuracy 0.7565
# Epoch 6 Batch 550 Loss 0.8638 Accuracy 0.7562
# Epoch 6 Batch 600 Loss 0.8646 Accuracy 0.7562
# Epoch 6 Batch 650 Loss 0.8631 Accuracy 0.7566
# Epoch 6 Batch 700 Loss 0.8658 Accuracy 0.7562
# Epoch 6 Batch 750 Loss 0.8630 Accuracy 0.7569
# Epoch 6 Loss 0.8630 Accuracy 0.7569
# Time taken for 1 epoch: 122.31 secs
#
# Epoch 6 Loss 0.7834 Accuracy 0.7771
# Time taken for 1 epoch: 24.37 secs
#
# Epoch 7 Batch 0 Loss 0.7408 Accuracy 0.7807
# Epoch 7 Batch 50 Loss 0.8349 Accuracy 0.7618
# Epoch 7 Batch 100 Loss 0.8499 Accuracy 0.7587
# Epoch 7 Batch 150 Loss 0.8528 Accuracy 0.7583
# Epoch 7 Batch 200 Loss 0.8551 Accuracy 0.7579
# Epoch 7 Batch 250 Loss 0.8507 Accuracy 0.7590
# Epoch 7 Batch 300 Loss 0.8518 Accuracy 0.7591
# Epoch 7 Batch 350 Loss 0.8507 Accuracy 0.7591
# Epoch 7 Batch 400 Loss 0.8498 Accuracy 0.7594
# Epoch 7 Batch 450 Loss 0.8470 Accuracy 0.7602
# Epoch 7 Batch 500 Loss 0.8438 Accuracy 0.7610
# Epoch 7 Batch 550 Loss 0.8411 Accuracy 0.7615
# Epoch 7 Batch 600 Loss 0.8426 Accuracy 0.7611
# Epoch 7 Batch 650 Loss 0.8403 Accuracy 0.7617
# Epoch 7 Batch 700 Loss 0.8399 Accuracy 0.7619
# Epoch 7 Batch 750 Loss 0.8400 Accuracy 0.7619
# Epoch 7 Loss 0.8404 Accuracy 0.7617
# Time taken for 1 epoch: 123.67 secs
#
# Epoch 7 Loss 0.7588 Accuracy 0.7818
# Time taken for 1 epoch: 23.94 secs
#
# Epoch 8 Batch 0 Loss 0.8185 Accuracy 0.7637
# Epoch 8 Batch 50 Loss 0.8337 Accuracy 0.7622
# Epoch 8 Batch 100 Loss 0.8296 Accuracy 0.7632
# Epoch 8 Batch 150 Loss 0.8222 Accuracy 0.7654
# Epoch 8 Batch 200 Loss 0.8215 Accuracy 0.7655
# Epoch 8 Batch 250 Loss 0.8214 Accuracy 0.7653
# Epoch 8 Batch 300 Loss 0.8218 Accuracy 0.7653
# Epoch 8 Batch 350 Loss 0.8198 Accuracy 0.7656
# Epoch 8 Batch 400 Loss 0.8186 Accuracy 0.7661
# Epoch 8 Batch 450 Loss 0.8170 Accuracy 0.7665
# Epoch 8 Batch 500 Loss 0.8167 Accuracy 0.7665
# Epoch 8 Batch 550 Loss 0.8196 Accuracy 0.7659
# Epoch 8 Batch 600 Loss 0.8186 Accuracy 0.7662
# Epoch 8 Batch 650 Loss 0.8173 Accuracy 0.7666
# Epoch 8 Batch 700 Loss 0.8183 Accuracy 0.7663
# Epoch 8 Batch 750 Loss 0.8181 Accuracy 0.7665
# Epoch 8 Loss 0.8178 Accuracy 0.7666
# Time taken for 1 epoch: 123.47 secs
#
# Epoch 8 Loss 0.7380 Accuracy 0.7875
# Time taken for 1 epoch: 25.01 secs
#
# Epoch 9 Batch 0 Loss 0.6878 Accuracy 0.7901
# Epoch 9 Batch 50 Loss 0.8169 Accuracy 0.7678
# Epoch 9 Batch 100 Loss 0.8048 Accuracy 0.7693
# Epoch 9 Batch 150 Loss 0.8041 Accuracy 0.7693
# Epoch 9 Batch 200 Loss 0.7999 Accuracy 0.7703
# Epoch 9 Batch 250 Loss 0.7979 Accuracy 0.7708
# Epoch 9 Batch 300 Loss 0.8006 Accuracy 0.7698
# Epoch 9 Batch 350 Loss 0.8020 Accuracy 0.7695
# Epoch 9 Batch 400 Loss 0.8012 Accuracy 0.7695
# Epoch 9 Batch 450 Loss 0.8032 Accuracy 0.7691
# Epoch 9 Batch 500 Loss 0.8013 Accuracy 0.7695
# Epoch 9 Batch 550 Loss 0.8007 Accuracy 0.7697
# Epoch 9 Batch 600 Loss 0.7985 Accuracy 0.7705
# Epoch 9 Batch 650 Loss 0.8001 Accuracy 0.7701
# Epoch 9 Batch 700 Loss 0.7988 Accuracy 0.7705
# Epoch 9 Batch 750 Loss 0.7998 Accuracy 0.7701
# Epoch 9 Loss 0.8002 Accuracy 0.7700
# Time taken for 1 epoch: 123.17 secs
#
# Epoch 9 Loss 0.7171 Accuracy 0.7914
# Time taken for 1 epoch: 24.83 secs
#
# Epoch 10 Batch 0 Loss 1.0374 Accuracy 0.7005
# Epoch 10 Batch 50 Loss 0.7893 Accuracy 0.7707
# Epoch 10 Batch 100 Loss 0.7780 Accuracy 0.7739
# Epoch 10 Batch 150 Loss 0.7741 Accuracy 0.7745
# Epoch 10 Batch 200 Loss 0.7802 Accuracy 0.7734
# Epoch 10 Batch 250 Loss 0.7801 Accuracy 0.7735
# Epoch 10 Batch 300 Loss 0.7791 Accuracy 0.7739
# Epoch 10 Batch 350 Loss 0.7784 Accuracy 0.7739
# Epoch 10 Batch 400 Loss 0.7778 Accuracy 0.7742
# Epoch 10 Batch 450 Loss 0.7811 Accuracy 0.7738
# Epoch 10 Batch 500 Loss 0.7838 Accuracy 0.7731
# Epoch 10 Batch 550 Loss 0.7824 Accuracy 0.7733
# Epoch 10 Batch 600 Loss 0.7827 Accuracy 0.7735
# Epoch 10 Batch 650 Loss 0.7831 Accuracy 0.7735
# Epoch 10 Batch 700 Loss 0.7838 Accuracy 0.7736
# Epoch 10 Batch 750 Loss 0.7842 Accuracy 0.7735
# Epoch 10 Loss 0.7848 Accuracy 0.7734
# Time taken for 1 epoch: 124.23 secs
#
# Epoch 10 Loss 0.6979 Accuracy 0.7954
# Time taken for 1 epoch: 24.77 secs
#
# Epoch 11 Batch 0 Loss 0.9797 Accuracy 0.7336
# Epoch 11 Batch 50 Loss 0.7565 Accuracy 0.7769
# Epoch 11 Batch 100 Loss 0.7642 Accuracy 0.7764
# Epoch 11 Batch 150 Loss 0.7671 Accuracy 0.7759
# Epoch 11 Batch 200 Loss 0.7657 Accuracy 0.7764
# Epoch 11 Batch 250 Loss 0.7662 Accuracy 0.7763
# Epoch 11 Batch 300 Loss 0.7676 Accuracy 0.7762
# Epoch 11 Batch 350 Loss 0.7700 Accuracy 0.7758
# Epoch 11 Batch 400 Loss 0.7668 Accuracy 0.7766
# Epoch 11 Batch 450 Loss 0.7707 Accuracy 0.7757
# Epoch 11 Batch 500 Loss 0.7716 Accuracy 0.7754
# Epoch 11 Batch 550 Loss 0.7720 Accuracy 0.7755
# Epoch 11 Batch 600 Loss 0.7724 Accuracy 0.7754
# Epoch 11 Batch 650 Loss 0.7709 Accuracy 0.7759
# Epoch 11 Batch 700 Loss 0.7704 Accuracy 0.7760
# Epoch 11 Batch 750 Loss 0.7694 Accuracy 0.7763
# Epoch 11 Loss 0.7696 Accuracy 0.7763
# Time taken for 1 epoch: 124.12 secs
#
# Epoch 11 Loss 0.6778 Accuracy 0.8009
# Time taken for 1 epoch: 24.81 secs
#
# Epoch 12 Batch 0 Loss 0.7607 Accuracy 0.7801
# Epoch 12 Batch 50 Loss 0.7565 Accuracy 0.7788
# Epoch 12 Batch 100 Loss 0.7416 Accuracy 0.7832
# Epoch 12 Batch 150 Loss 0.7549 Accuracy 0.7799
# Epoch 12 Batch 200 Loss 0.7525 Accuracy 0.7799
# Epoch 12 Batch 250 Loss 0.7492 Accuracy 0.7806
# Epoch 12 Batch 300 Loss 0.7479 Accuracy 0.7808
# Epoch 12 Batch 350 Loss 0.7506 Accuracy 0.7802
# Epoch 12 Batch 400 Loss 0.7507 Accuracy 0.7801
# Epoch 12 Batch 450 Loss 0.7515 Accuracy 0.7799
# Epoch 12 Batch 500 Loss 0.7529 Accuracy 0.7797
# Epoch 12 Batch 550 Loss 0.7531 Accuracy 0.7798
# Epoch 12 Batch 600 Loss 0.7525 Accuracy 0.7802
# Epoch 12 Batch 650 Loss 0.7536 Accuracy 0.7800
# Epoch 12 Batch 700 Loss 0.7540 Accuracy 0.7799
# Epoch 12 Batch 750 Loss 0.7533 Accuracy 0.7801
# Epoch 12 Loss 0.7539 Accuracy 0.7801
# Time taken for 1 epoch: 124.95 secs
#
# Epoch 12 Loss 0.6694 Accuracy 0.8021
# Time taken for 1 epoch: 24.30 secs
#
# Epoch 13 Batch 0 Loss 0.9498 Accuracy 0.7392
# Epoch 13 Batch 50 Loss 0.7428 Accuracy 0.7804
# Epoch 13 Batch 100 Loss 0.7363 Accuracy 0.7824
# Epoch 13 Batch 150 Loss 0.7333 Accuracy 0.7829
# Epoch 13 Batch 200 Loss 0.7316 Accuracy 0.7836
# Epoch 13 Batch 250 Loss 0.7317 Accuracy 0.7837
# Epoch 13 Batch 300 Loss 0.7349 Accuracy 0.7831
# Epoch 13 Batch 350 Loss 0.7364 Accuracy 0.7829
# Epoch 13 Batch 400 Loss 0.7376 Accuracy 0.7826
# Epoch 13 Batch 450 Loss 0.7370 Accuracy 0.7830
# Epoch 13 Batch 500 Loss 0.7379 Accuracy 0.7828
# Epoch 13 Batch 550 Loss 0.7406 Accuracy 0.7823
# Epoch 13 Batch 600 Loss 0.7410 Accuracy 0.7822
# Epoch 13 Batch 650 Loss 0.7400 Accuracy 0.7824
# Epoch 13 Batch 700 Loss 0.7412 Accuracy 0.7823
# Epoch 13 Batch 750 Loss 0.7405 Accuracy 0.7824
# Epoch 13 Loss 0.7410 Accuracy 0.7823
# Time taken for 1 epoch: 124.81 secs
#
# Epoch 13 Loss 0.6468 Accuracy 0.8083
# Time taken for 1 epoch: 24.18 secs
#
# Epoch 14 Batch 0 Loss 0.6426 Accuracy 0.8010
# Epoch 14 Batch 50 Loss 0.7378 Accuracy 0.7843
# Epoch 14 Batch 100 Loss 0.7280 Accuracy 0.7851
# Epoch 14 Batch 150 Loss 0.7267 Accuracy 0.7855
# Epoch 14 Batch 200 Loss 0.7267 Accuracy 0.7853
# Epoch 14 Batch 250 Loss 0.7237 Accuracy 0.7860
# Epoch 14 Batch 300 Loss 0.7227 Accuracy 0.7861
# Epoch 14 Batch 350 Loss 0.7226 Accuracy 0.7862
# Epoch 14 Batch 400 Loss 0.7227 Accuracy 0.7863
# Epoch 14 Batch 450 Loss 0.7209 Accuracy 0.7867
# Epoch 14 Batch 500 Loss 0.7246 Accuracy 0.7860
# Epoch 14 Batch 550 Loss 0.7240 Accuracy 0.7862
# Epoch 14 Batch 600 Loss 0.7232 Accuracy 0.7863
# Epoch 14 Batch 650 Loss 0.7244 Accuracy 0.7860
# Epoch 14 Batch 700 Loss 0.7250 Accuracy 0.7859
# Epoch 14 Batch 750 Loss 0.7246 Accuracy 0.7861
# Epoch 14 Loss 0.7264 Accuracy 0.7857
# Time taken for 1 epoch: 123.85 secs
#
# Epoch 14 Loss 0.6341 Accuracy 0.8107
# Time taken for 1 epoch: 24.57 secs
#
# Epoch 15 Batch 0 Loss 0.7582 Accuracy 0.7799
# Epoch 15 Batch 50 Loss 0.7367 Accuracy 0.7826
# Epoch 15 Batch 100 Loss 0.7203 Accuracy 0.7867
# Epoch 15 Batch 150 Loss 0.7132 Accuracy 0.7882
# Epoch 15 Batch 200 Loss 0.7155 Accuracy 0.7874
# Epoch 15 Batch 250 Loss 0.7179 Accuracy 0.7872
# Epoch 15 Batch 300 Loss 0.7156 Accuracy 0.7879
# Epoch 15 Batch 350 Loss 0.7147 Accuracy 0.7881
# Epoch 15 Batch 400 Loss 0.7149 Accuracy 0.7880
# Epoch 15 Batch 450 Loss 0.7144 Accuracy 0.7882
# Epoch 15 Batch 500 Loss 0.7140 Accuracy 0.7883
# Epoch 15 Batch 550 Loss 0.7137 Accuracy 0.7884
# Epoch 15 Batch 600 Loss 0.7163 Accuracy 0.7878
# Epoch 15 Batch 650 Loss 0.7166 Accuracy 0.7877
# Epoch 15 Batch 700 Loss 0.7156 Accuracy 0.7879
# Epoch 15 Batch 750 Loss 0.7151 Accuracy 0.7881
# Epoch 15 Loss 0.7154 Accuracy 0.7880
# Time taken for 1 epoch: 124.86 secs
#
# Epoch 15 Loss 0.6155 Accuracy 0.8154
# Time taken for 1 epoch: 24.35 secs
#
# Epoch 16 Batch 0 Loss 0.6746 Accuracy 0.7993
# Epoch 16 Batch 50 Loss 0.7153 Accuracy 0.7881
# Epoch 16 Batch 100 Loss 0.7023 Accuracy 0.7911
# Epoch 16 Batch 150 Loss 0.7033 Accuracy 0.7907
# Epoch 16 Batch 200 Loss 0.6993 Accuracy 0.7912
# Epoch 16 Batch 250 Loss 0.7035 Accuracy 0.7905
# Epoch 16 Batch 300 Loss 0.7060 Accuracy 0.7898
# Epoch 16 Batch 350 Loss 0.7041 Accuracy 0.7904
# Epoch 16 Batch 400 Loss 0.7023 Accuracy 0.7908
# Epoch 16 Batch 450 Loss 0.7029 Accuracy 0.7908
# Epoch 16 Batch 500 Loss 0.7037 Accuracy 0.7906
# Epoch 16 Batch 550 Loss 0.7042 Accuracy 0.7905
# Epoch 16 Batch 600 Loss 0.7039 Accuracy 0.7906
# Epoch 16 Batch 650 Loss 0.7039 Accuracy 0.7907
# Epoch 16 Batch 700 Loss 0.7046 Accuracy 0.7905
# Epoch 16 Batch 750 Loss 0.7041 Accuracy 0.7907
# Epoch 16 Loss 0.7049 Accuracy 0.7905
# Time taken for 1 epoch: 125.01 secs
#
# Epoch 16 Loss 0.6114 Accuracy 0.8166
# Time taken for 1 epoch: 25.12 secs
#
# Epoch 17 Batch 0 Loss 0.5685 Accuracy 0.8126
# Epoch 17 Batch 50 Loss 0.6813 Accuracy 0.7947
# Epoch 17 Batch 100 Loss 0.6889 Accuracy 0.7933
# Epoch 17 Batch 150 Loss 0.6924 Accuracy 0.7926
# Epoch 17 Batch 200 Loss 0.6918 Accuracy 0.7929
# Epoch 17 Batch 250 Loss 0.6914 Accuracy 0.7930
# Epoch 17 Batch 300 Loss 0.6933 Accuracy 0.7927
# Epoch 17 Batch 350 Loss 0.6966 Accuracy 0.7918
# Epoch 17 Batch 400 Loss 0.6974 Accuracy 0.7916
# Epoch 17 Batch 450 Loss 0.6977 Accuracy 0.7916
# Epoch 17 Batch 500 Loss 0.6997 Accuracy 0.7910
# Epoch 17 Batch 550 Loss 0.6981 Accuracy 0.7916
# Epoch 17 Batch 600 Loss 0.6959 Accuracy 0.7920
# Epoch 17 Batch 650 Loss 0.6951 Accuracy 0.7922
# Epoch 17 Batch 700 Loss 0.6946 Accuracy 0.7924
# Epoch 17 Batch 750 Loss 0.6946 Accuracy 0.7924
# Epoch 17 Loss 0.6940 Accuracy 0.7925
# Time taken for 1 epoch: 123.56 secs
#
# Epoch 17 Loss 0.6015 Accuracy 0.8186
# Time taken for 1 epoch: 25.14 secs
#
# Epoch 18 Batch 0 Loss 0.7249 Accuracy 0.7918
# Epoch 18 Batch 50 Loss 0.6990 Accuracy 0.7913
# Epoch 18 Batch 100 Loss 0.6878 Accuracy 0.7940
# Epoch 18 Batch 150 Loss 0.6817 Accuracy 0.7953
# Epoch 18 Batch 200 Loss 0.6827 Accuracy 0.7953
# Epoch 18 Batch 250 Loss 0.6845 Accuracy 0.7948
# Epoch 18 Batch 300 Loss 0.6842 Accuracy 0.7950
# Epoch 18 Batch 350 Loss 0.6823 Accuracy 0.7956
# Epoch 18 Batch 400 Loss 0.6856 Accuracy 0.7948
# Epoch 18 Batch 450 Loss 0.6838 Accuracy 0.7953
# Epoch 18 Batch 500 Loss 0.6842 Accuracy 0.7953
# Epoch 18 Batch 550 Loss 0.6854 Accuracy 0.7949
# Epoch 18 Batch 600 Loss 0.6846 Accuracy 0.7950
# Epoch 18 Batch 650 Loss 0.6861 Accuracy 0.7946
# Epoch 18 Batch 700 Loss 0.6867 Accuracy 0.7944
# Epoch 18 Batch 750 Loss 0.6857 Accuracy 0.7947
# Epoch 18 Loss 0.6846 Accuracy 0.7950
# Time taken for 1 epoch: 124.11 secs
#
# Epoch 18 Loss 0.5836 Accuracy 0.8233
# Time taken for 1 epoch: 24.58 secs
#
# Epoch 19 Batch 0 Loss 0.6457 Accuracy 0.8064
# Epoch 19 Batch 50 Loss 0.6752 Accuracy 0.7968
# Epoch 19 Batch 100 Loss 0.6778 Accuracy 0.7963
# Epoch 19 Batch 150 Loss 0.6767 Accuracy 0.7967
# Epoch 19 Batch 200 Loss 0.6751 Accuracy 0.7969
# Epoch 19 Batch 250 Loss 0.6739 Accuracy 0.7974
# Epoch 19 Batch 300 Loss 0.6755 Accuracy 0.7969
# Epoch 19 Batch 350 Loss 0.6761 Accuracy 0.7968
# Epoch 19 Batch 400 Loss 0.6755 Accuracy 0.7971
# Epoch 19 Batch 450 Loss 0.6763 Accuracy 0.7969
# Epoch 19 Batch 500 Loss 0.6731 Accuracy 0.7974
# Epoch 19 Batch 550 Loss 0.6721 Accuracy 0.7977
# Epoch 19 Batch 600 Loss 0.6714 Accuracy 0.7979
# Epoch 19 Batch 650 Loss 0.6723 Accuracy 0.7979
# Epoch 19 Batch 700 Loss 0.6731 Accuracy 0.7977
# Epoch 19 Batch 750 Loss 0.6733 Accuracy 0.7978
# Epoch 19 Loss 0.6742 Accuracy 0.7975
# Time taken for 1 epoch: 123.88 secs
#
# Epoch 19 Loss 0.5752 Accuracy 0.8252
# Time taken for 1 epoch: 25.31 secs
#
# Epoch 20 Batch 0 Loss 0.7529 Accuracy 0.7748
# Epoch 20 Batch 50 Loss 0.6897 Accuracy 0.7936
# Epoch 20 Batch 100 Loss 0.6617 Accuracy 0.8009
# Epoch 20 Batch 150 Loss 0.6609 Accuracy 0.8010
# Epoch 20 Batch 200 Loss 0.6636 Accuracy 0.8001
# Epoch 20 Batch 250 Loss 0.6681 Accuracy 0.7991
# Epoch 20 Batch 300 Loss 0.6634 Accuracy 0.8002
# Epoch 20 Batch 350 Loss 0.6640 Accuracy 0.8002
# Epoch 20 Batch 400 Loss 0.6659 Accuracy 0.7995
# Epoch 20 Batch 450 Loss 0.6654 Accuracy 0.7996
# Epoch 20 Batch 500 Loss 0.6648 Accuracy 0.7997
# Epoch 20 Batch 550 Loss 0.6652 Accuracy 0.7997
# Epoch 20 Batch 600 Loss 0.6656 Accuracy 0.7996
# Epoch 20 Batch 650 Loss 0.6653 Accuracy 0.7996
# Epoch 20 Batch 700 Loss 0.6652 Accuracy 0.7998
# Epoch 20 Batch 750 Loss 0.6662 Accuracy 0.7994
# Epoch 20 Loss 0.6662 Accuracy 0.7994
# Time taken for 1 epoch: 123.52 secs
#
# Epoch 20 Loss 0.5681 Accuracy 0.8267
# Time taken for 1 epoch: 24.23 secs
#
# Epoch 21 Batch 0 Loss 0.5927 Accuracy 0.8138
# Epoch 21 Batch 50 Loss 0.6582 Accuracy 0.8001
# Epoch 21 Batch 100 Loss 0.6561 Accuracy 0.8008
# Epoch 21 Batch 150 Loss 0.6599 Accuracy 0.7995
# Epoch 21 Batch 200 Loss 0.6599 Accuracy 0.7996
# Epoch 21 Batch 250 Loss 0.6606 Accuracy 0.7999
# Epoch 21 Batch 300 Loss 0.6603 Accuracy 0.8002
# Epoch 21 Batch 350 Loss 0.6585 Accuracy 0.8006
# Epoch 21 Batch 400 Loss 0.6571 Accuracy 0.8008
# Epoch 21 Batch 450 Loss 0.6598 Accuracy 0.8001
# Epoch 21 Batch 500 Loss 0.6586 Accuracy 0.8006
# Epoch 21 Batch 550 Loss 0.6571 Accuracy 0.8011
# Epoch 21 Batch 600 Loss 0.6583 Accuracy 0.8007
# Epoch 21 Batch 650 Loss 0.6582 Accuracy 0.8009
# Epoch 21 Batch 700 Loss 0.6580 Accuracy 0.8010
# Epoch 21 Batch 750 Loss 0.6579 Accuracy 0.8010
# Epoch 21 Loss 0.6576 Accuracy 0.8011
# Time taken for 1 epoch: 125.75 secs
#
# Epoch 21 Loss 0.5580 Accuracy 0.8303
# Time taken for 1 epoch: 24.55 secs
#
# Epoch 22 Batch 0 Loss 0.5613 Accuracy 0.8259
# Epoch 22 Batch 50 Loss 0.6540 Accuracy 0.8005
# Epoch 22 Batch 100 Loss 0.6564 Accuracy 0.8006
# Epoch 22 Batch 150 Loss 0.6510 Accuracy 0.8026
# Epoch 22 Batch 200 Loss 0.6490 Accuracy 0.8036
# Epoch 22 Batch 250 Loss 0.6482 Accuracy 0.8039
# Epoch 22 Batch 300 Loss 0.6470 Accuracy 0.8041
# Epoch 22 Batch 350 Loss 0.6465 Accuracy 0.8043
# Epoch 22 Batch 400 Loss 0.6478 Accuracy 0.8039
# Epoch 22 Batch 450 Loss 0.6477 Accuracy 0.8036
# Epoch 22 Batch 500 Loss 0.6477 Accuracy 0.8035
# Epoch 22 Batch 550 Loss 0.6489 Accuracy 0.8031
# Epoch 22 Batch 600 Loss 0.6504 Accuracy 0.8027
# Epoch 22 Batch 650 Loss 0.6508 Accuracy 0.8026
# Epoch 22 Batch 700 Loss 0.6496 Accuracy 0.8029
# Epoch 22 Batch 750 Loss 0.6495 Accuracy 0.8030
# Epoch 22 Loss 0.6497 Accuracy 0.8029
# Time taken for 1 epoch: 123.99 secs
#
# Epoch 22 Loss 0.5467 Accuracy 0.8329
# Time taken for 1 epoch: 25.30 secs
#
# Epoch 23 Batch 0 Loss 0.5987 Accuracy 0.8126
# Epoch 23 Batch 50 Loss 0.6464 Accuracy 0.8033
# Epoch 23 Batch 100 Loss 0.6479 Accuracy 0.8021
# Epoch 23 Batch 150 Loss 0.6406 Accuracy 0.8042
# Epoch 23 Batch 200 Loss 0.6403 Accuracy 0.8041
# Epoch 23 Batch 250 Loss 0.6424 Accuracy 0.8039
# Epoch 23 Batch 300 Loss 0.6391 Accuracy 0.8049
# Epoch 23 Batch 350 Loss 0.6387 Accuracy 0.8052
# Epoch 23 Batch 400 Loss 0.6391 Accuracy 0.8050
# Epoch 23 Batch 450 Loss 0.6386 Accuracy 0.8053
# Epoch 23 Batch 500 Loss 0.6373 Accuracy 0.8058
# Epoch 23 Batch 550 Loss 0.6395 Accuracy 0.8052
# Epoch 23 Batch 600 Loss 0.6422 Accuracy 0.8046
# Epoch 23 Batch 650 Loss 0.6416 Accuracy 0.8049
# Epoch 23 Batch 700 Loss 0.6411 Accuracy 0.8049
# Epoch 23 Batch 750 Loss 0.6410 Accuracy 0.8050
# Epoch 23 Loss 0.6415 Accuracy 0.8049
# Time taken for 1 epoch: 124.00 secs
#
# Epoch 23 Loss 0.5385 Accuracy 0.8354
# Time taken for 1 epoch: 24.37 secs
#
# Epoch 24 Batch 0 Loss 0.6129 Accuracy 0.8158
# Epoch 24 Batch 50 Loss 0.6289 Accuracy 0.8086
# Epoch 24 Batch 100 Loss 0.6360 Accuracy 0.8064
# Epoch 24 Batch 150 Loss 0.6359 Accuracy 0.8060
# Epoch 24 Batch 200 Loss 0.6317 Accuracy 0.8069
# Epoch 24 Batch 250 Loss 0.6306 Accuracy 0.8074
# Epoch 24 Batch 300 Loss 0.6321 Accuracy 0.8069
# Epoch 24 Batch 350 Loss 0.6305 Accuracy 0.8071
# Epoch 24 Batch 400 Loss 0.6329 Accuracy 0.8065
# Epoch 24 Batch 450 Loss 0.6337 Accuracy 0.8063
# Epoch 24 Batch 500 Loss 0.6340 Accuracy 0.8062
# Epoch 24 Batch 550 Loss 0.6356 Accuracy 0.8060
# Epoch 24 Batch 600 Loss 0.6354 Accuracy 0.8061
# Epoch 24 Batch 650 Loss 0.6363 Accuracy 0.8059
# Epoch 24 Batch 700 Loss 0.6362 Accuracy 0.8060
# Epoch 24 Batch 750 Loss 0.6353 Accuracy 0.8063
# Epoch 24 Loss 0.6353 Accuracy 0.8062
# Time taken for 1 epoch: 124.66 secs
#
# Epoch 24 Loss 0.5292 Accuracy 0.8369
# Time taken for 1 epoch: 25.08 secs
#
# Epoch 25 Batch 0 Loss 0.5907 Accuracy 0.8092
# Epoch 25 Batch 50 Loss 0.6325 Accuracy 0.8067
# Epoch 25 Batch 100 Loss 0.6252 Accuracy 0.8083
# Epoch 25 Batch 150 Loss 0.6259 Accuracy 0.8080
# Epoch 25 Batch 200 Loss 0.6249 Accuracy 0.8083
# Epoch 25 Batch 250 Loss 0.6215 Accuracy 0.8094
# Epoch 25 Batch 300 Loss 0.6258 Accuracy 0.8085
# Epoch 25 Batch 350 Loss 0.6242 Accuracy 0.8090
# Epoch 25 Batch 400 Loss 0.6238 Accuracy 0.8089
# Epoch 25 Batch 450 Loss 0.6249 Accuracy 0.8086
# Epoch 25 Batch 500 Loss 0.6247 Accuracy 0.8086
# Epoch 25 Batch 550 Loss 0.6246 Accuracy 0.8088
# Epoch 25 Batch 600 Loss 0.6259 Accuracy 0.8084
# Epoch 25 Batch 650 Loss 0.6253 Accuracy 0.8085
# Epoch 25 Batch 700 Loss 0.6277 Accuracy 0.8079
# Epoch 25 Batch 750 Loss 0.6279 Accuracy 0.8079
# Epoch 25 Loss 0.6281 Accuracy 0.8079
# Time taken for 1 epoch: 123.60 secs
#
# Epoch 25 Loss 0.5230 Accuracy 0.8393
# Time taken for 1 epoch: 24.91 secs
#
# Epoch 26 Batch 0 Loss 0.6647 Accuracy 0.7928
# Epoch 26 Batch 50 Loss 0.6296 Accuracy 0.8059
# Epoch 26 Batch 100 Loss 0.6182 Accuracy 0.8103
# Epoch 26 Batch 150 Loss 0.6171 Accuracy 0.8108
# Epoch 26 Batch 200 Loss 0.6205 Accuracy 0.8100
# Epoch 26 Batch 250 Loss 0.6197 Accuracy 0.8101
# Epoch 26 Batch 300 Loss 0.6188 Accuracy 0.8102
# Epoch 26 Batch 350 Loss 0.6196 Accuracy 0.8098
# Epoch 26 Batch 400 Loss 0.6171 Accuracy 0.8104
# Epoch 26 Batch 450 Loss 0.6194 Accuracy 0.8099
# Epoch 26 Batch 500 Loss 0.6199 Accuracy 0.8100
# Epoch 26 Batch 550 Loss 0.6201 Accuracy 0.8100
# Epoch 26 Batch 600 Loss 0.6206 Accuracy 0.8099
# Epoch 26 Batch 650 Loss 0.6215 Accuracy 0.8097
# Epoch 26 Batch 700 Loss 0.6216 Accuracy 0.8096
# Epoch 26 Batch 750 Loss 0.6220 Accuracy 0.8095
# Epoch 26 Loss 0.6213 Accuracy 0.8096
# Time taken for 1 epoch: 123.66 secs
#
# Epoch 26 Loss 0.5101 Accuracy 0.8422
# Time taken for 1 epoch: 25.03 secs
#
# Epoch 27 Batch 0 Loss 0.6382 Accuracy 0.8077
# Epoch 27 Batch 50 Loss 0.6172 Accuracy 0.8089
# Epoch 27 Batch 100 Loss 0.6127 Accuracy 0.8109
# Epoch 27 Batch 150 Loss 0.6099 Accuracy 0.8118
# Epoch 27 Batch 200 Loss 0.6106 Accuracy 0.8122
# Epoch 27 Batch 250 Loss 0.6135 Accuracy 0.8115
# Epoch 27 Batch 300 Loss 0.6117 Accuracy 0.8120
# Epoch 27 Batch 350 Loss 0.6111 Accuracy 0.8123
# Epoch 27 Batch 400 Loss 0.6118 Accuracy 0.8121
# Epoch 27 Batch 450 Loss 0.6129 Accuracy 0.8118
# Epoch 27 Batch 500 Loss 0.6144 Accuracy 0.8114
# Epoch 27 Batch 550 Loss 0.6137 Accuracy 0.8115
# Epoch 27 Batch 600 Loss 0.6144 Accuracy 0.8114
# Epoch 27 Batch 650 Loss 0.6159 Accuracy 0.8111
# Epoch 27 Batch 700 Loss 0.6166 Accuracy 0.8109
# Epoch 27 Batch 750 Loss 0.6159 Accuracy 0.8110
# Epoch 27 Loss 0.6153 Accuracy 0.8111
# Time taken for 1 epoch: 124.74 secs
#
# Epoch 27 Loss 0.5090 Accuracy 0.8428
# Time taken for 1 epoch: 25.23 secs
#
# Epoch 28 Batch 0 Loss 0.7519 Accuracy 0.7818
# Epoch 28 Batch 50 Loss 0.6230 Accuracy 0.8086
# Epoch 28 Batch 100 Loss 0.6089 Accuracy 0.8127
# Epoch 28 Batch 150 Loss 0.6065 Accuracy 0.8128
# Epoch 28 Batch 200 Loss 0.6107 Accuracy 0.8118
# Epoch 28 Batch 250 Loss 0.6094 Accuracy 0.8125
# Epoch 28 Batch 300 Loss 0.6085 Accuracy 0.8126
# Epoch 28 Batch 350 Loss 0.6091 Accuracy 0.8122
# Epoch 28 Batch 400 Loss 0.6075 Accuracy 0.8127
# Epoch 28 Batch 450 Loss 0.6074 Accuracy 0.8127
# Epoch 28 Batch 500 Loss 0.6087 Accuracy 0.8123
# Epoch 28 Batch 550 Loss 0.6085 Accuracy 0.8123
# Epoch 28 Batch 600 Loss 0.6086 Accuracy 0.8124
# Epoch 28 Batch 650 Loss 0.6089 Accuracy 0.8124
# Epoch 28 Batch 700 Loss 0.6095 Accuracy 0.8123
# Epoch 28 Batch 750 Loss 0.6106 Accuracy 0.8120
# Epoch 28 Loss 0.6104 Accuracy 0.8122
# Time taken for 1 epoch: 123.68 secs
#
# Epoch 28 Loss 0.5039 Accuracy 0.8440
# Time taken for 1 epoch: 24.49 secs
#
# Epoch 29 Batch 0 Loss 0.6996 Accuracy 0.7839
# Epoch 29 Batch 50 Loss 0.6146 Accuracy 0.8107
# Epoch 29 Batch 100 Loss 0.6039 Accuracy 0.8141
# Epoch 29 Batch 150 Loss 0.6017 Accuracy 0.8145
# Epoch 29 Batch 200 Loss 0.5981 Accuracy 0.8149
# Epoch 29 Batch 250 Loss 0.5985 Accuracy 0.8147
# Epoch 29 Batch 300 Loss 0.6000 Accuracy 0.8145
# Epoch 29 Batch 350 Loss 0.6004 Accuracy 0.8145
# Epoch 29 Batch 400 Loss 0.5981 Accuracy 0.8153
# Epoch 29 Batch 450 Loss 0.6008 Accuracy 0.8146
# Epoch 29 Batch 500 Loss 0.6019 Accuracy 0.8144
# Epoch 29 Batch 550 Loss 0.6023 Accuracy 0.8144
# Epoch 29 Batch 600 Loss 0.6031 Accuracy 0.8143
# Epoch 29 Batch 650 Loss 0.6051 Accuracy 0.8137
# Epoch 29 Batch 700 Loss 0.6052 Accuracy 0.8138
# Epoch 29 Batch 750 Loss 0.6044 Accuracy 0.8140
# Epoch 29 Loss 0.6039 Accuracy 0.8141
# Time taken for 1 epoch: 122.93 secs
#
# Epoch 29 Loss 0.4922 Accuracy 0.8474
# Time taken for 1 epoch: 24.92 secs
#
# Epoch 30 Batch 0 Loss 0.7158 Accuracy 0.7867
# Epoch 30 Batch 50 Loss 0.6013 Accuracy 0.8140
# Epoch 30 Batch 100 Loss 0.5942 Accuracy 0.8161
# Epoch 30 Batch 150 Loss 0.5982 Accuracy 0.8146
# Epoch 30 Batch 200 Loss 0.5978 Accuracy 0.8147
# Epoch 30 Batch 250 Loss 0.5968 Accuracy 0.8149
# Epoch 30 Batch 300 Loss 0.5978 Accuracy 0.8150
# Epoch 30 Batch 350 Loss 0.5986 Accuracy 0.8151
# Epoch 30 Batch 400 Loss 0.5970 Accuracy 0.8157
# Epoch 30 Batch 450 Loss 0.5971 Accuracy 0.8156
# Epoch 30 Batch 500 Loss 0.5973 Accuracy 0.8157
# Epoch 30 Batch 550 Loss 0.5977 Accuracy 0.8156
# Epoch 30 Batch 600 Loss 0.5995 Accuracy 0.8151
# Epoch 30 Batch 650 Loss 0.5985 Accuracy 0.8153
# Epoch 30 Batch 700 Loss 0.5983 Accuracy 0.8154
# Epoch 30 Batch 750 Loss 0.5996 Accuracy 0.8151
# Epoch 30 Loss 0.5993 Accuracy 0.8152
# Time taken for 1 epoch: 122.75 secs
#
# Epoch 30 Loss 0.4877 Accuracy 0.8486
# Time taken for 1 epoch: 24.60 secs
#
# Epoch 31 Batch 0 Loss 0.7248 Accuracy 0.7770
# Epoch 31 Batch 50 Loss 0.5891 Accuracy 0.8170
# Epoch 31 Batch 100 Loss 0.5862 Accuracy 0.8180
# Epoch 31 Batch 150 Loss 0.5907 Accuracy 0.8167
# Epoch 31 Batch 200 Loss 0.5874 Accuracy 0.8178
# Epoch 31 Batch 250 Loss 0.5882 Accuracy 0.8175
# Epoch 31 Batch 300 Loss 0.5888 Accuracy 0.8174
# Epoch 31 Batch 350 Loss 0.5904 Accuracy 0.8173
# Epoch 31 Batch 400 Loss 0.5900 Accuracy 0.8174
# Epoch 31 Batch 450 Loss 0.5888 Accuracy 0.8177
# Epoch 31 Batch 500 Loss 0.5899 Accuracy 0.8175
# Epoch 31 Batch 550 Loss 0.5900 Accuracy 0.8174
# Epoch 31 Batch 600 Loss 0.5905 Accuracy 0.8173
# Epoch 31 Batch 650 Loss 0.5901 Accuracy 0.8175
# Epoch 31 Batch 700 Loss 0.5894 Accuracy 0.8176
# Epoch 31 Batch 750 Loss 0.5916 Accuracy 0.8171
# Epoch 31 Loss 0.5920 Accuracy 0.8170
# Time taken for 1 epoch: 124.35 secs
#
# Epoch 31 Loss 0.4777 Accuracy 0.8513
# Time taken for 1 epoch: 24.64 secs
#
# Epoch 32 Batch 0 Loss 0.4641 Accuracy 0.8483
# Epoch 32 Batch 50 Loss 0.5751 Accuracy 0.8191
# Epoch 32 Batch 100 Loss 0.5755 Accuracy 0.8202
# Epoch 32 Batch 150 Loss 0.5856 Accuracy 0.8177
# Epoch 32 Batch 200 Loss 0.5867 Accuracy 0.8179
# Epoch 32 Batch 250 Loss 0.5842 Accuracy 0.8189
# Epoch 32 Batch 300 Loss 0.5850 Accuracy 0.8187
# Epoch 32 Batch 350 Loss 0.5855 Accuracy 0.8187
# Epoch 32 Batch 400 Loss 0.5846 Accuracy 0.8188
# Epoch 32 Batch 450 Loss 0.5864 Accuracy 0.8183
# Epoch 32 Batch 500 Loss 0.5864 Accuracy 0.8184
# Epoch 32 Batch 550 Loss 0.5866 Accuracy 0.8185
# Epoch 32 Batch 600 Loss 0.5872 Accuracy 0.8183
# Epoch 32 Batch 650 Loss 0.5876 Accuracy 0.8180
# Epoch 32 Batch 700 Loss 0.5873 Accuracy 0.8182
# Epoch 32 Batch 750 Loss 0.5880 Accuracy 0.8180
# Epoch 32 Loss 0.5878 Accuracy 0.8180
# Time taken for 1 epoch: 124.49 secs
#
# Epoch 32 Loss 0.4768 Accuracy 0.8517
# Time taken for 1 epoch: 25.31 secs
#
# Epoch 33 Batch 0 Loss 0.6064 Accuracy 0.8184
# Epoch 33 Batch 50 Loss 0.5831 Accuracy 0.8183
# Epoch 33 Batch 100 Loss 0.5788 Accuracy 0.8192
# Epoch 33 Batch 150 Loss 0.5762 Accuracy 0.8200
# Epoch 33 Batch 200 Loss 0.5762 Accuracy 0.8201
# Epoch 33 Batch 250 Loss 0.5772 Accuracy 0.8201
# Epoch 33 Batch 300 Loss 0.5787 Accuracy 0.8197
# Epoch 33 Batch 350 Loss 0.5801 Accuracy 0.8195
# Epoch 33 Batch 400 Loss 0.5820 Accuracy 0.8190
# Epoch 33 Batch 450 Loss 0.5809 Accuracy 0.8194
# Epoch 33 Batch 500 Loss 0.5807 Accuracy 0.8195
# Epoch 33 Batch 550 Loss 0.5793 Accuracy 0.8199
# Epoch 33 Batch 600 Loss 0.5803 Accuracy 0.8197
# Epoch 33 Batch 650 Loss 0.5821 Accuracy 0.8192
# Epoch 33 Batch 700 Loss 0.5825 Accuracy 0.8191
# Epoch 33 Batch 750 Loss 0.5834 Accuracy 0.8189
# Epoch 33 Loss 0.5829 Accuracy 0.8190
# Time taken for 1 epoch: 123.74 secs
#
# Epoch 33 Loss 0.4729 Accuracy 0.8519
# Time taken for 1 epoch: 25.76 secs
#
# Epoch 34 Batch 0 Loss 0.6187 Accuracy 0.8114
# Epoch 34 Batch 50 Loss 0.5764 Accuracy 0.8206
# Epoch 34 Batch 100 Loss 0.5738 Accuracy 0.8210
# Epoch 34 Batch 150 Loss 0.5819 Accuracy 0.8191
# Epoch 34 Batch 200 Loss 0.5762 Accuracy 0.8205
# Epoch 34 Batch 250 Loss 0.5734 Accuracy 0.8214
# Epoch 34 Batch 300 Loss 0.5765 Accuracy 0.8204
# Epoch 34 Batch 350 Loss 0.5776 Accuracy 0.8201
# Epoch 34 Batch 400 Loss 0.5782 Accuracy 0.8200
# Epoch 34 Batch 450 Loss 0.5788 Accuracy 0.8199
# Epoch 34 Batch 500 Loss 0.5788 Accuracy 0.8200
# Epoch 34 Batch 550 Loss 0.5794 Accuracy 0.8197
# Epoch 34 Batch 600 Loss 0.5791 Accuracy 0.8198
# Epoch 34 Batch 650 Loss 0.5781 Accuracy 0.8201
# Epoch 34 Batch 700 Loss 0.5777 Accuracy 0.8203
# Epoch 34 Batch 750 Loss 0.5777 Accuracy 0.8202
# Epoch 34 Loss 0.5784 Accuracy 0.8201
# Time taken for 1 epoch: 123.81 secs
#
# Epoch 34 Loss 0.4615 Accuracy 0.8562
# Time taken for 1 epoch: 24.58 secs
#
# Epoch 35 Batch 0 Loss 0.7770 Accuracy 0.7595
# Epoch 35 Batch 50 Loss 0.5718 Accuracy 0.8213
# Epoch 35 Batch 100 Loss 0.5709 Accuracy 0.8212
# Epoch 35 Batch 150 Loss 0.5696 Accuracy 0.8221
# Epoch 35 Batch 200 Loss 0.5681 Accuracy 0.8223
# Epoch 35 Batch 250 Loss 0.5695 Accuracy 0.8221
# Epoch 35 Batch 300 Loss 0.5710 Accuracy 0.8217
# Epoch 35 Batch 350 Loss 0.5706 Accuracy 0.8219
# Epoch 35 Batch 400 Loss 0.5704 Accuracy 0.8216
# Epoch 35 Batch 450 Loss 0.5710 Accuracy 0.8215
# Epoch 35 Batch 500 Loss 0.5733 Accuracy 0.8209
# Epoch 35 Batch 550 Loss 0.5730 Accuracy 0.8212
# Epoch 35 Batch 600 Loss 0.5735 Accuracy 0.8212
# Epoch 35 Batch 650 Loss 0.5726 Accuracy 0.8215
# Epoch 35 Batch 700 Loss 0.5719 Accuracy 0.8217
# Epoch 35 Batch 750 Loss 0.5722 Accuracy 0.8215
# Epoch 35 Loss 0.5726 Accuracy 0.8215
# Time taken for 1 epoch: 124.00 secs
#
# Epoch 35 Loss 0.4607 Accuracy 0.8559
# Time taken for 1 epoch: 25.11 secs
#
# Epoch 36 Batch 0 Loss 0.5626 Accuracy 0.8177
# Epoch 36 Batch 50 Loss 0.5752 Accuracy 0.8188
# Epoch 36 Batch 100 Loss 0.5657 Accuracy 0.8223
# Epoch 36 Batch 150 Loss 0.5672 Accuracy 0.8224
# Epoch 36 Batch 200 Loss 0.5666 Accuracy 0.8225
# Epoch 36 Batch 250 Loss 0.5647 Accuracy 0.8232
# Epoch 36 Batch 300 Loss 0.5643 Accuracy 0.8232
# Epoch 36 Batch 350 Loss 0.5689 Accuracy 0.8222
# Epoch 36 Batch 400 Loss 0.5715 Accuracy 0.8215
# Epoch 36 Batch 450 Loss 0.5700 Accuracy 0.8220
# Epoch 36 Batch 500 Loss 0.5682 Accuracy 0.8225
# Epoch 36 Batch 550 Loss 0.5695 Accuracy 0.8221
# Epoch 36 Batch 600 Loss 0.5696 Accuracy 0.8220
# Epoch 36 Batch 650 Loss 0.5694 Accuracy 0.8221
# Epoch 36 Batch 700 Loss 0.5689 Accuracy 0.8222
# Epoch 36 Batch 750 Loss 0.5682 Accuracy 0.8225
# Epoch 36 Loss 0.5685 Accuracy 0.8224
# Time taken for 1 epoch: 123.44 secs
#
# Epoch 36 Loss 0.4518 Accuracy 0.8586
# Time taken for 1 epoch: 25.45 secs
#
# Epoch 37 Batch 0 Loss 0.5296 Accuracy 0.8414
# Epoch 37 Batch 50 Loss 0.5623 Accuracy 0.8235
# Epoch 37 Batch 100 Loss 0.5677 Accuracy 0.8224
# Epoch 37 Batch 150 Loss 0.5676 Accuracy 0.8226
# Epoch 37 Batch 200 Loss 0.5668 Accuracy 0.8231
# Epoch 37 Batch 250 Loss 0.5636 Accuracy 0.8239
# Epoch 37 Batch 300 Loss 0.5606 Accuracy 0.8245
# Epoch 37 Batch 350 Loss 0.5584 Accuracy 0.8252
# Epoch 37 Batch 400 Loss 0.5587 Accuracy 0.8250
# Epoch 37 Batch 450 Loss 0.5603 Accuracy 0.8249
# Epoch 37 Batch 500 Loss 0.5634 Accuracy 0.8239
# Epoch 37 Batch 550 Loss 0.5635 Accuracy 0.8240
# Epoch 37 Batch 600 Loss 0.5638 Accuracy 0.8240
# Epoch 37 Batch 650 Loss 0.5641 Accuracy 0.8238
# Epoch 37 Batch 700 Loss 0.5633 Accuracy 0.8241
# Epoch 37 Batch 750 Loss 0.5635 Accuracy 0.8241
# Epoch 37 Loss 0.5637 Accuracy 0.8240
# Time taken for 1 epoch: 122.54 secs
#
# Epoch 37 Loss 0.4465 Accuracy 0.8601
# Time taken for 1 epoch: 25.25 secs
#
# Epoch 38 Batch 0 Loss 0.7510 Accuracy 0.7674
# Epoch 38 Batch 50 Loss 0.5684 Accuracy 0.8217
# Epoch 38 Batch 100 Loss 0.5589 Accuracy 0.8247
# Epoch 38 Batch 150 Loss 0.5582 Accuracy 0.8251
# Epoch 38 Batch 200 Loss 0.5559 Accuracy 0.8258
# Epoch 38 Batch 250 Loss 0.5557 Accuracy 0.8258
# Epoch 38 Batch 300 Loss 0.5558 Accuracy 0.8258
# Epoch 38 Batch 350 Loss 0.5558 Accuracy 0.8260
# Epoch 38 Batch 400 Loss 0.5560 Accuracy 0.8259
# Epoch 38 Batch 450 Loss 0.5568 Accuracy 0.8257
# Epoch 38 Batch 500 Loss 0.5561 Accuracy 0.8258
# Epoch 38 Batch 550 Loss 0.5561 Accuracy 0.8259
# Epoch 38 Batch 600 Loss 0.5564 Accuracy 0.8257
# Epoch 38 Batch 650 Loss 0.5576 Accuracy 0.8254
# Epoch 38 Batch 700 Loss 0.5587 Accuracy 0.8250
# Epoch 38 Batch 750 Loss 0.5602 Accuracy 0.8245
# Epoch 38 Loss 0.5609 Accuracy 0.8244
# Time taken for 1 epoch: 123.04 secs
#
# Epoch 38 Loss 0.4429 Accuracy 0.8614
# Time taken for 1 epoch: 26.20 secs
#
# Epoch 39 Batch 0 Loss 0.5437 Accuracy 0.8347
# Epoch 39 Batch 50 Loss 0.5647 Accuracy 0.8231
# Epoch 39 Batch 100 Loss 0.5550 Accuracy 0.8260
# Epoch 39 Batch 150 Loss 0.5534 Accuracy 0.8266
# Epoch 39 Batch 200 Loss 0.5534 Accuracy 0.8266
# Epoch 39 Batch 250 Loss 0.5543 Accuracy 0.8263
# Epoch 39 Batch 300 Loss 0.5569 Accuracy 0.8255
# Epoch 39 Batch 350 Loss 0.5575 Accuracy 0.8254
# Epoch 39 Batch 400 Loss 0.5566 Accuracy 0.8256
# Epoch 39 Batch 450 Loss 0.5559 Accuracy 0.8258
# Epoch 39 Batch 500 Loss 0.5567 Accuracy 0.8256
# Epoch 39 Batch 550 Loss 0.5553 Accuracy 0.8259
# Epoch 39 Batch 600 Loss 0.5560 Accuracy 0.8258
# Epoch 39 Batch 650 Loss 0.5565 Accuracy 0.8257
# Epoch 39 Batch 700 Loss 0.5564 Accuracy 0.8256
# Epoch 39 Batch 750 Loss 0.5567 Accuracy 0.8255
# Epoch 39 Loss 0.5565 Accuracy 0.8256
# Time taken for 1 epoch: 125.08 secs
#
# Epoch 39 Loss 0.4372 Accuracy 0.8621
# Time taken for 1 epoch: 24.85 secs
#
# Epoch 40 Batch 0 Loss 0.5255 Accuracy 0.8357
# Epoch 40 Batch 50 Loss 0.5589 Accuracy 0.8249
# Epoch 40 Batch 100 Loss 0.5646 Accuracy 0.8233
# Epoch 40 Batch 150 Loss 0.5564 Accuracy 0.8252
# Epoch 40 Batch 200 Loss 0.5535 Accuracy 0.8260
# Epoch 40 Batch 250 Loss 0.5509 Accuracy 0.8267
# Epoch 40 Batch 300 Loss 0.5531 Accuracy 0.8262
# Epoch 40 Batch 350 Loss 0.5508 Accuracy 0.8269
# Epoch 40 Batch 400 Loss 0.5501 Accuracy 0.8268
# Epoch 40 Batch 450 Loss 0.5510 Accuracy 0.8266
# Epoch 40 Batch 500 Loss 0.5508 Accuracy 0.8267
# Epoch 40 Batch 550 Loss 0.5506 Accuracy 0.8269
# Epoch 40 Batch 600 Loss 0.5508 Accuracy 0.8268
# Epoch 40 Batch 650 Loss 0.5519 Accuracy 0.8266
# Epoch 40 Batch 700 Loss 0.5530 Accuracy 0.8264
# Epoch 40 Batch 750 Loss 0.5531 Accuracy 0.8265
# Epoch 40 Loss 0.5534 Accuracy 0.8265
# Time taken for 1 epoch: 124.05 secs
#
# Epoch 40 Loss 0.4321 Accuracy 0.8643
# Time taken for 1 epoch: 24.84 secs
#
# Epoch 41 Batch 0 Loss 0.5148 Accuracy 0.8372
# Epoch 41 Batch 50 Loss 0.5560 Accuracy 0.8259
# Epoch 41 Batch 100 Loss 0.5512 Accuracy 0.8266
# Epoch 41 Batch 150 Loss 0.5516 Accuracy 0.8268
# Epoch 41 Batch 200 Loss 0.5516 Accuracy 0.8268
# Epoch 41 Batch 250 Loss 0.5494 Accuracy 0.8273
# Epoch 41 Batch 300 Loss 0.5514 Accuracy 0.8267
# Epoch 41 Batch 350 Loss 0.5521 Accuracy 0.8266
# Epoch 41 Batch 400 Loss 0.5535 Accuracy 0.8263
# Epoch 41 Batch 450 Loss 0.5507 Accuracy 0.8271
# Epoch 41 Batch 500 Loss 0.5498 Accuracy 0.8273
# Epoch 41 Batch 550 Loss 0.5508 Accuracy 0.8270
# Epoch 41 Batch 600 Loss 0.5507 Accuracy 0.8270
# Epoch 41 Batch 650 Loss 0.5516 Accuracy 0.8267
# Epoch 41 Batch 700 Loss 0.5490 Accuracy 0.8276
# Epoch 41 Batch 750 Loss 0.5486 Accuracy 0.8277
# Epoch 41 Loss 0.5487 Accuracy 0.8277
# Time taken for 1 epoch: 124.89 secs
#
# Epoch 41 Loss 0.4334 Accuracy 0.8638
# Time taken for 1 epoch: 24.79 secs
#
# Epoch 42 Batch 0 Loss 0.6607 Accuracy 0.7915
# Epoch 42 Batch 50 Loss 0.5378 Accuracy 0.8299
# Epoch 42 Batch 100 Loss 0.5325 Accuracy 0.8315
# Epoch 42 Batch 150 Loss 0.5340 Accuracy 0.8318
# Epoch 42 Batch 200 Loss 0.5380 Accuracy 0.8303
# Epoch 42 Batch 250 Loss 0.5356 Accuracy 0.8311
# Epoch 42 Batch 300 Loss 0.5397 Accuracy 0.8302
# Epoch 42 Batch 350 Loss 0.5401 Accuracy 0.8303
# Epoch 42 Batch 400 Loss 0.5393 Accuracy 0.8304
# Epoch 42 Batch 450 Loss 0.5386 Accuracy 0.8307
# Epoch 42 Batch 500 Loss 0.5419 Accuracy 0.8298
# Epoch 42 Batch 550 Loss 0.5442 Accuracy 0.8291
# Epoch 42 Batch 600 Loss 0.5442 Accuracy 0.8291
# Epoch 42 Batch 650 Loss 0.5435 Accuracy 0.8292
# Epoch 42 Batch 700 Loss 0.5435 Accuracy 0.8291
# Epoch 42 Batch 750 Loss 0.5444 Accuracy 0.8289
# Epoch 42 Loss 0.5448 Accuracy 0.8287
# Time taken for 1 epoch: 122.13 secs
#
# Epoch 42 Loss 0.4231 Accuracy 0.8669
# Time taken for 1 epoch: 24.84 secs
#
# Epoch 43 Batch 0 Loss 0.7295 Accuracy 0.7900
# Epoch 43 Batch 50 Loss 0.5356 Accuracy 0.8293
# Epoch 43 Batch 100 Loss 0.5285 Accuracy 0.8319
# Epoch 43 Batch 150 Loss 0.5292 Accuracy 0.8323
# Epoch 43 Batch 200 Loss 0.5331 Accuracy 0.8313
# Epoch 43 Batch 250 Loss 0.5355 Accuracy 0.8307
# Epoch 43 Batch 300 Loss 0.5356 Accuracy 0.8306
# Epoch 43 Batch 350 Loss 0.5390 Accuracy 0.8299
# Epoch 43 Batch 400 Loss 0.5410 Accuracy 0.8293
# Epoch 43 Batch 450 Loss 0.5385 Accuracy 0.8300
# Epoch 43 Batch 500 Loss 0.5398 Accuracy 0.8296
# Epoch 43 Batch 550 Loss 0.5396 Accuracy 0.8297
# Epoch 43 Batch 600 Loss 0.5401 Accuracy 0.8296
# Epoch 43 Batch 650 Loss 0.5410 Accuracy 0.8293
# Epoch 43 Batch 700 Loss 0.5419 Accuracy 0.8291
# Epoch 43 Batch 750 Loss 0.5423 Accuracy 0.8291
# Epoch 43 Loss 0.5420 Accuracy 0.8292
# Time taken for 1 epoch: 125.13 secs
#
# Epoch 43 Loss 0.4252 Accuracy 0.8664
# Time taken for 1 epoch: 26.10 secs
#
# Epoch 44 Batch 0 Loss 0.6502 Accuracy 0.7964
# Epoch 44 Batch 50 Loss 0.5324 Accuracy 0.8310
# Epoch 44 Batch 100 Loss 0.5378 Accuracy 0.8304
# Epoch 44 Batch 150 Loss 0.5385 Accuracy 0.8302
# Epoch 44 Batch 200 Loss 0.5388 Accuracy 0.8302
# Epoch 44 Batch 250 Loss 0.5364 Accuracy 0.8307
# Epoch 44 Batch 300 Loss 0.5355 Accuracy 0.8310
# Epoch 44 Batch 350 Loss 0.5354 Accuracy 0.8310
# Epoch 44 Batch 400 Loss 0.5362 Accuracy 0.8307
# Epoch 44 Batch 450 Loss 0.5369 Accuracy 0.8304
# Epoch 44 Batch 500 Loss 0.5357 Accuracy 0.8308
# Epoch 44 Batch 550 Loss 0.5358 Accuracy 0.8308
# Epoch 44 Batch 600 Loss 0.5360 Accuracy 0.8308
# Epoch 44 Batch 650 Loss 0.5364 Accuracy 0.8307
# Epoch 44 Batch 700 Loss 0.5365 Accuracy 0.8307
# Epoch 44 Batch 750 Loss 0.5371 Accuracy 0.8305
# Epoch 44 Loss 0.5374 Accuracy 0.8304
# Time taken for 1 epoch: 123.41 secs
#
# Epoch 44 Loss 0.4175 Accuracy 0.8683
# Time taken for 1 epoch: 24.06 secs
#
# Epoch 45 Batch 0 Loss 0.5531 Accuracy 0.8231
# Epoch 45 Batch 50 Loss 0.5375 Accuracy 0.8292
# Epoch 45 Batch 100 Loss 0.5225 Accuracy 0.8335
# Epoch 45 Batch 150 Loss 0.5283 Accuracy 0.8325
# Epoch 45 Batch 200 Loss 0.5287 Accuracy 0.8322
# Epoch 45 Batch 250 Loss 0.5299 Accuracy 0.8324
# Epoch 45 Batch 300 Loss 0.5321 Accuracy 0.8320
# Epoch 45 Batch 350 Loss 0.5336 Accuracy 0.8317
# Epoch 45 Batch 400 Loss 0.5332 Accuracy 0.8319
# Epoch 45 Batch 450 Loss 0.5321 Accuracy 0.8321
# Epoch 45 Batch 500 Loss 0.5317 Accuracy 0.8321
# Epoch 45 Batch 550 Loss 0.5327 Accuracy 0.8319
# Epoch 45 Batch 600 Loss 0.5340 Accuracy 0.8315
# Epoch 45 Batch 650 Loss 0.5328 Accuracy 0.8319
# Epoch 45 Batch 700 Loss 0.5334 Accuracy 0.8316
# Epoch 45 Batch 750 Loss 0.5339 Accuracy 0.8315
# Epoch 45 Loss 0.5338 Accuracy 0.8315
# Time taken for 1 epoch: 122.54 secs
#
# Epoch 45 Loss 0.4147 Accuracy 0.8693
# Time taken for 1 epoch: 25.09 secs
#
# Epoch 46 Batch 0 Loss 0.5439 Accuracy 0.8271
# Epoch 46 Batch 50 Loss 0.5287 Accuracy 0.8318
# Epoch 46 Batch 100 Loss 0.5272 Accuracy 0.8324
# Epoch 46 Batch 150 Loss 0.5286 Accuracy 0.8324
# Epoch 46 Batch 200 Loss 0.5291 Accuracy 0.8323
# Epoch 46 Batch 250 Loss 0.5281 Accuracy 0.8328
# Epoch 46 Batch 300 Loss 0.5296 Accuracy 0.8324
# Epoch 46 Batch 350 Loss 0.5290 Accuracy 0.8325
# Epoch 46 Batch 400 Loss 0.5291 Accuracy 0.8324
# Epoch 46 Batch 450 Loss 0.5299 Accuracy 0.8321
# Epoch 46 Batch 500 Loss 0.5306 Accuracy 0.8319
# Epoch 46 Batch 550 Loss 0.5293 Accuracy 0.8324
# Epoch 46 Batch 600 Loss 0.5307 Accuracy 0.8321
# Epoch 46 Batch 650 Loss 0.5307 Accuracy 0.8321
# Epoch 46 Batch 700 Loss 0.5317 Accuracy 0.8318
# Epoch 46 Batch 750 Loss 0.5322 Accuracy 0.8316
# Epoch 46 Loss 0.5319 Accuracy 0.8318
# Time taken for 1 epoch: 124.49 secs
#
# Epoch 46 Loss 0.4118 Accuracy 0.8704
# Time taken for 1 epoch: 26.01 secs
#
# Epoch 47 Batch 0 Loss 0.5832 Accuracy 0.8062
# Epoch 47 Batch 50 Loss 0.5295 Accuracy 0.8334
# Epoch 47 Batch 100 Loss 0.5193 Accuracy 0.8354
# Epoch 47 Batch 150 Loss 0.5204 Accuracy 0.8347
# Epoch 47 Batch 200 Loss 0.5217 Accuracy 0.8343
# Epoch 47 Batch 250 Loss 0.5214 Accuracy 0.8346
# Epoch 47 Batch 300 Loss 0.5215 Accuracy 0.8346
# Epoch 47 Batch 350 Loss 0.5233 Accuracy 0.8343
# Epoch 47 Batch 400 Loss 0.5234 Accuracy 0.8345
# Epoch 47 Batch 450 Loss 0.5245 Accuracy 0.8341
# Epoch 47 Batch 500 Loss 0.5254 Accuracy 0.8339
# Epoch 47 Batch 550 Loss 0.5265 Accuracy 0.8336
# Epoch 47 Batch 600 Loss 0.5276 Accuracy 0.8333
# Epoch 47 Batch 650 Loss 0.5276 Accuracy 0.8332
# Epoch 47 Batch 700 Loss 0.5278 Accuracy 0.8332
# Epoch 47 Batch 750 Loss 0.5276 Accuracy 0.8332
# Epoch 47 Loss 0.5274 Accuracy 0.8332
# Time taken for 1 epoch: 125.28 secs
#
# Epoch 47 Loss 0.4015 Accuracy 0.8736
# Time taken for 1 epoch: 24.10 secs
#
# Epoch 48 Batch 0 Loss 0.4291 Accuracy 0.8570
# Epoch 48 Batch 50 Loss 0.5157 Accuracy 0.8353
# Epoch 48 Batch 100 Loss 0.5242 Accuracy 0.8330
# Epoch 48 Batch 150 Loss 0.5226 Accuracy 0.8334
# Epoch 48 Batch 200 Loss 0.5215 Accuracy 0.8341
# Epoch 48 Batch 250 Loss 0.5219 Accuracy 0.8340
# Epoch 48 Batch 300 Loss 0.5199 Accuracy 0.8348
# Epoch 48 Batch 350 Loss 0.5184 Accuracy 0.8351
# Epoch 48 Batch 400 Loss 0.5202 Accuracy 0.8348
# Epoch 48 Batch 450 Loss 0.5199 Accuracy 0.8349
# Epoch 48 Batch 500 Loss 0.5202 Accuracy 0.8349
# Epoch 48 Batch 550 Loss 0.5215 Accuracy 0.8344
# Epoch 48 Batch 600 Loss 0.5220 Accuracy 0.8343
# Epoch 48 Batch 650 Loss 0.5240 Accuracy 0.8338
# Epoch 48 Batch 700 Loss 0.5240 Accuracy 0.8338
# Epoch 48 Batch 750 Loss 0.5250 Accuracy 0.8337
# Epoch 48 Loss 0.5243 Accuracy 0.8339
# Time taken for 1 epoch: 123.46 secs
#
# Epoch 48 Loss 0.4053 Accuracy 0.8723
# Time taken for 1 epoch: 24.75 secs
#
# Epoch 49 Batch 0 Loss 0.6155 Accuracy 0.8067
# Epoch 49 Batch 50 Loss 0.5294 Accuracy 0.8324
# Epoch 49 Batch 100 Loss 0.5229 Accuracy 0.8337
# Epoch 49 Batch 150 Loss 0.5180 Accuracy 0.8352
# Epoch 49 Batch 200 Loss 0.5211 Accuracy 0.8340
# Epoch 49 Batch 250 Loss 0.5197 Accuracy 0.8346
# Epoch 49 Batch 300 Loss 0.5197 Accuracy 0.8347
# Epoch 49 Batch 350 Loss 0.5202 Accuracy 0.8348
# Epoch 49 Batch 400 Loss 0.5186 Accuracy 0.8351
# Epoch 49 Batch 450 Loss 0.5175 Accuracy 0.8354
# Epoch 49 Batch 500 Loss 0.5181 Accuracy 0.8351
# Epoch 49 Batch 550 Loss 0.5177 Accuracy 0.8353
# Epoch 49 Batch 600 Loss 0.5183 Accuracy 0.8353
# Epoch 49 Batch 650 Loss 0.5206 Accuracy 0.8347
# Epoch 49 Batch 700 Loss 0.5219 Accuracy 0.8344
# Epoch 49 Batch 750 Loss 0.5224 Accuracy 0.8343
# Epoch 49 Loss 0.5218 Accuracy 0.8345
# Time taken for 1 epoch: 124.35 secs
#
# Epoch 49 Loss 0.4009 Accuracy 0.8732
# Time taken for 1 epoch: 25.16 secs
#
# Epoch 50 Batch 0 Loss 0.4059 Accuracy 0.8679
# Epoch 50 Batch 50 Loss 0.5069 Accuracy 0.8379
# Epoch 50 Batch 100 Loss 0.5134 Accuracy 0.8359
# Epoch 50 Batch 150 Loss 0.5172 Accuracy 0.8352
# Epoch 50 Batch 200 Loss 0.5182 Accuracy 0.8349
# Epoch 50 Batch 250 Loss 0.5203 Accuracy 0.8345
# Epoch 50 Batch 300 Loss 0.5199 Accuracy 0.8343
# Epoch 50 Batch 350 Loss 0.5196 Accuracy 0.8345
# Epoch 50 Batch 400 Loss 0.5188 Accuracy 0.8347
# Epoch 50 Batch 450 Loss 0.5189 Accuracy 0.8347
# Epoch 50 Batch 500 Loss 0.5192 Accuracy 0.8345
# Epoch 50 Batch 550 Loss 0.5172 Accuracy 0.8351
# Epoch 50 Batch 600 Loss 0.5171 Accuracy 0.8353
# Epoch 50 Batch 650 Loss 0.5179 Accuracy 0.8352
# Epoch 50 Batch 700 Loss 0.5174 Accuracy 0.8353
# Epoch 50 Batch 750 Loss 0.5188 Accuracy 0.8351
# Epoch 50 Loss 0.5191 Accuracy 0.8350
# Time taken for 1 epoch: 123.21 secs
#
# Epoch 50 Loss 0.3973 Accuracy 0.8747
# Time taken for 1 epoch: 24.24 secs
#
# Epoch 51 Batch 0 Loss 0.5250 Accuracy 0.8319
# Epoch 51 Batch 50 Loss 0.5361 Accuracy 0.8303
# Epoch 51 Batch 100 Loss 0.5240 Accuracy 0.8338
# Epoch 51 Batch 150 Loss 0.5207 Accuracy 0.8346
# Epoch 51 Batch 200 Loss 0.5137 Accuracy 0.8366
# Epoch 51 Batch 250 Loss 0.5116 Accuracy 0.8371
# Epoch 51 Batch 300 Loss 0.5108 Accuracy 0.8372
# Epoch 51 Batch 350 Loss 0.5098 Accuracy 0.8376
# Epoch 51 Batch 400 Loss 0.5086 Accuracy 0.8380
# Epoch 51 Batch 450 Loss 0.5107 Accuracy 0.8375
# Epoch 51 Batch 500 Loss 0.5112 Accuracy 0.8375
# Epoch 51 Batch 550 Loss 0.5123 Accuracy 0.8372
# Epoch 51 Batch 600 Loss 0.5127 Accuracy 0.8372
# Epoch 51 Batch 650 Loss 0.5134 Accuracy 0.8369
# Epoch 51 Batch 700 Loss 0.5154 Accuracy 0.8365
# Epoch 51 Batch 750 Loss 0.5161 Accuracy 0.8363
# Epoch 51 Loss 0.5157 Accuracy 0.8364
# Time taken for 1 epoch: 123.39 secs
#
# Epoch 51 Loss 0.3948 Accuracy 0.8749
# Time taken for 1 epoch: 24.93 secs
#
# Epoch 52 Batch 0 Loss 0.5228 Accuracy 0.8291
# Epoch 52 Batch 50 Loss 0.4887 Accuracy 0.8432
# Epoch 52 Batch 100 Loss 0.4973 Accuracy 0.8409
# Epoch 52 Batch 150 Loss 0.5027 Accuracy 0.8394
# Epoch 52 Batch 200 Loss 0.5078 Accuracy 0.8380
# Epoch 52 Batch 250 Loss 0.5056 Accuracy 0.8386
# Epoch 52 Batch 300 Loss 0.5065 Accuracy 0.8383
# Epoch 52 Batch 350 Loss 0.5082 Accuracy 0.8379
# Epoch 52 Batch 400 Loss 0.5090 Accuracy 0.8377
# Epoch 52 Batch 450 Loss 0.5086 Accuracy 0.8380
# Epoch 52 Batch 500 Loss 0.5091 Accuracy 0.8378
# Epoch 52 Batch 550 Loss 0.5107 Accuracy 0.8373
# Epoch 52 Batch 600 Loss 0.5120 Accuracy 0.8370
# Epoch 52 Batch 650 Loss 0.5119 Accuracy 0.8371
# Epoch 52 Batch 700 Loss 0.5127 Accuracy 0.8370
# Epoch 52 Batch 750 Loss 0.5127 Accuracy 0.8371
# Epoch 52 Loss 0.5120 Accuracy 0.8373
# Time taken for 1 epoch: 123.60 secs
#
# Epoch 52 Loss 0.3876 Accuracy 0.8772
# Time taken for 1 epoch: 25.39 secs
#
# Epoch 53 Batch 0 Loss 0.5182 Accuracy 0.8251
# Epoch 53 Batch 50 Loss 0.5099 Accuracy 0.8369
# Epoch 53 Batch 100 Loss 0.5038 Accuracy 0.8395
# Epoch 53 Batch 150 Loss 0.5009 Accuracy 0.8405
# Epoch 53 Batch 200 Loss 0.5027 Accuracy 0.8399
# Epoch 53 Batch 250 Loss 0.5036 Accuracy 0.8397
# Epoch 53 Batch 300 Loss 0.5050 Accuracy 0.8393
# Epoch 53 Batch 350 Loss 0.5059 Accuracy 0.8389
# Epoch 53 Batch 400 Loss 0.5079 Accuracy 0.8384
# Epoch 53 Batch 450 Loss 0.5069 Accuracy 0.8387
# Epoch 53 Batch 500 Loss 0.5073 Accuracy 0.8386
# Epoch 53 Batch 550 Loss 0.5074 Accuracy 0.8386
# Epoch 53 Batch 600 Loss 0.5073 Accuracy 0.8386
# Epoch 53 Batch 650 Loss 0.5082 Accuracy 0.8382
# Epoch 53 Batch 700 Loss 0.5092 Accuracy 0.8379
# Epoch 53 Batch 750 Loss 0.5099 Accuracy 0.8377
# Epoch 53 Loss 0.5096 Accuracy 0.8378
# Time taken for 1 epoch: 123.88 secs
#
# Epoch 53 Loss 0.3829 Accuracy 0.8794
# Time taken for 1 epoch: 24.34 secs
#
# Epoch 54 Batch 0 Loss 0.4803 Accuracy 0.8399
# Epoch 54 Batch 50 Loss 0.5079 Accuracy 0.8378
# Epoch 54 Batch 100 Loss 0.5119 Accuracy 0.8373
# Epoch 54 Batch 150 Loss 0.5155 Accuracy 0.8359
# Epoch 54 Batch 200 Loss 0.5106 Accuracy 0.8372
# Epoch 54 Batch 250 Loss 0.5083 Accuracy 0.8378
# Epoch 54 Batch 300 Loss 0.5066 Accuracy 0.8383
# Epoch 54 Batch 350 Loss 0.5096 Accuracy 0.8376
# Epoch 54 Batch 400 Loss 0.5089 Accuracy 0.8379
# Epoch 54 Batch 450 Loss 0.5085 Accuracy 0.8381
# Epoch 54 Batch 500 Loss 0.5091 Accuracy 0.8379
# Epoch 54 Batch 550 Loss 0.5101 Accuracy 0.8377
# Epoch 54 Batch 600 Loss 0.5098 Accuracy 0.8378
# Epoch 54 Batch 650 Loss 0.5091 Accuracy 0.8380
# ...
# Epoch 83 Batch 200 Loss 0.4459 Accuracy 0.8540
# Epoch 83 Batch 250 Loss 0.4448 Accuracy 0.8544
# Epoch 83 Batch 300 Loss 0.4473 Accuracy 0.8537
# Epoch 83 Batch 350 Loss 0.4454 Accuracy 0.8545
# Epoch 83 Batch 400 Loss 0.4445 Accuracy 0.8548
# Epoch 83 Batch 450 Loss 0.4449 Accuracy 0.8548
# Epoch 83 Batch 500 Loss 0.4445 Accuracy 0.8550
# Epoch 83 Batch 550 Loss 0.4455 Accuracy 0.8548
# Epoch 83 Batch 600 Loss 0.4475 Accuracy 0.8543
# Epoch 83 Batch 650 Loss 0.4477 Accuracy 0.8542
# Epoch 83 Batch 700 Loss 0.4467 Accuracy 0.8545
# Epoch 83 Batch 750 Loss 0.4475 Accuracy 0.8543
# Epoch 83 Loss 0.4482 Accuracy 0.8541
# Time taken for 1 epoch: 124.93 secs
#
# Epoch 83 Loss 0.3095 Accuracy 0.9018
# Time taken for 1 epoch: 25.43 secs
#
# Epoch 84 Batch 0 Loss 0.4442 Accuracy 0.8438
# Epoch 84 Batch 50 Loss 0.4533 Accuracy 0.8528
# Epoch 84 Batch 100 Loss 0.4466 Accuracy 0.8539
# Epoch 84 Batch 150 Loss 0.4427 Accuracy 0.8551
# Epoch 84 Batch 200 Loss 0.4479 Accuracy 0.8537
# Epoch 84 Batch 250 Loss 0.4474 Accuracy 0.8541
# Epoch 84 Batch 300 Loss 0.4468 Accuracy 0.8545
# Epoch 84 Batch 350 Loss 0.4448 Accuracy 0.8551
# Epoch 84 Batch 400 Loss 0.4459 Accuracy 0.8549
# Epoch 84 Batch 450 Loss 0.4454 Accuracy 0.8550
# Epoch 84 Batch 500 Loss 0.4454 Accuracy 0.8550
# Epoch 84 Batch 550 Loss 0.4455 Accuracy 0.8550
# Epoch 84 Batch 600 Loss 0.4457 Accuracy 0.8550
# Epoch 84 Batch 650 Loss 0.4452 Accuracy 0.8552
# Epoch 84 Batch 700 Loss 0.4454 Accuracy 0.8551
# Epoch 84 Batch 750 Loss 0.4461 Accuracy 0.8549
# Epoch 84 Loss 0.4465 Accuracy 0.8547
# Time taken for 1 epoch: 122.94 secs
#
# Epoch 84 Loss 0.3090 Accuracy 0.9015
# Time taken for 1 epoch: 25.68 secs
#
# Epoch 85 Batch 0 Loss 0.4773 Accuracy 0.8357
# Epoch 85 Batch 50 Loss 0.4374 Accuracy 0.8567
# Epoch 85 Batch 100 Loss 0.4450 Accuracy 0.8544
# Epoch 85 Batch 150 Loss 0.4448 Accuracy 0.8547
# Epoch 85 Batch 200 Loss 0.4421 Accuracy 0.8553
# Epoch 85 Batch 250 Loss 0.4424 Accuracy 0.8555
# Epoch 85 Batch 300 Loss 0.4436 Accuracy 0.8552
# Epoch 85 Batch 350 Loss 0.4448 Accuracy 0.8548
# Epoch 85 Batch 400 Loss 0.4459 Accuracy 0.8546
# Epoch 85 Batch 450 Loss 0.4455 Accuracy 0.8548
# Epoch 85 Batch 500 Loss 0.4457 Accuracy 0.8547
# Epoch 85 Batch 550 Loss 0.4458 Accuracy 0.8547
# Epoch 85 Batch 600 Loss 0.4457 Accuracy 0.8548
# Epoch 85 Batch 650 Loss 0.4452 Accuracy 0.8550
# Epoch 85 Batch 700 Loss 0.4455 Accuracy 0.8550
# Epoch 85 Batch 750 Loss 0.4453 Accuracy 0.8551
# Epoch 85 Loss 0.4455 Accuracy 0.8550
# Time taken for 1 epoch: 124.10 secs
#
# Epoch 85 Loss 0.3080 Accuracy 0.9017
# Time taken for 1 epoch: 25.23 secs
#
# Epoch 86 Batch 0 Loss 0.7915 Accuracy 0.7696
# Epoch 86 Batch 50 Loss 0.4528 Accuracy 0.8527
# Epoch 86 Batch 100 Loss 0.4469 Accuracy 0.8550
# Epoch 86 Batch 150 Loss 0.4431 Accuracy 0.8561
# Epoch 86 Batch 200 Loss 0.4409 Accuracy 0.8566
# Epoch 86 Batch 250 Loss 0.4418 Accuracy 0.8562
# Epoch 86 Batch 300 Loss 0.4395 Accuracy 0.8569
# Epoch 86 Batch 350 Loss 0.4400 Accuracy 0.8568
# Epoch 86 Batch 400 Loss 0.4372 Accuracy 0.8574
# Epoch 86 Batch 450 Loss 0.4383 Accuracy 0.8569
# Epoch 86 Batch 500 Loss 0.4417 Accuracy 0.8560
# Epoch 86 Batch 550 Loss 0.4423 Accuracy 0.8558
# Epoch 86 Batch 600 Loss 0.4428 Accuracy 0.8557
# Epoch 86 Batch 650 Loss 0.4428 Accuracy 0.8556
# Epoch 86 Batch 700 Loss 0.4435 Accuracy 0.8554
# Epoch 86 Batch 750 Loss 0.4430 Accuracy 0.8554
# Epoch 86 Loss 0.4434 Accuracy 0.8553
# Time taken for 1 epoch: 123.54 secs
#
# Epoch 86 Loss 0.3070 Accuracy 0.9029
# Time taken for 1 epoch: 24.04 secs
#
# Epoch 87 Batch 0 Loss 0.5338 Accuracy 0.8307
# Epoch 87 Batch 50 Loss 0.4452 Accuracy 0.8543
# Epoch 87 Batch 100 Loss 0.4423 Accuracy 0.8557
# Epoch 87 Batch 150 Loss 0.4455 Accuracy 0.8549
# Epoch 87 Batch 200 Loss 0.4417 Accuracy 0.8560
# Epoch 87 Batch 250 Loss 0.4391 Accuracy 0.8566
# Epoch 87 Batch 300 Loss 0.4394 Accuracy 0.8567
# Epoch 87 Batch 350 Loss 0.4393 Accuracy 0.8568
# Epoch 87 Batch 400 Loss 0.4405 Accuracy 0.8565
# Epoch 87 Batch 450 Loss 0.4408 Accuracy 0.8564
# Epoch 87 Batch 500 Loss 0.4426 Accuracy 0.8558
# Epoch 87 Batch 550 Loss 0.4425 Accuracy 0.8559
# Epoch 87 Batch 600 Loss 0.4433 Accuracy 0.8557
# Epoch 87 Batch 650 Loss 0.4420 Accuracy 0.8560
# Epoch 87 Batch 700 Loss 0.4422 Accuracy 0.8560
# Epoch 87 Batch 750 Loss 0.4412 Accuracy 0.8562
# Epoch 87 Loss 0.4412 Accuracy 0.8562
# Time taken for 1 epoch: 124.09 secs
#
# Epoch 87 Loss 0.3067 Accuracy 0.9025
# Time taken for 1 epoch: 25.57 secs
#
# Epoch 88 Batch 0 Loss 0.3387 Accuracy 0.8801
# Epoch 88 Batch 50 Loss 0.4259 Accuracy 0.8608
# Epoch 88 Batch 100 Loss 0.4375 Accuracy 0.8573
# Epoch 88 Batch 150 Loss 0.4360 Accuracy 0.8577
# Epoch 88 Batch 200 Loss 0.4329 Accuracy 0.8585
# Epoch 88 Batch 250 Loss 0.4352 Accuracy 0.8576
# Epoch 88 Batch 300 Loss 0.4325 Accuracy 0.8583
# Epoch 88 Batch 350 Loss 0.4327 Accuracy 0.8586
# Epoch 88 Batch 400 Loss 0.4325 Accuracy 0.8587
# Epoch 88 Batch 450 Loss 0.4325 Accuracy 0.8588
# Epoch 88 Batch 500 Loss 0.4331 Accuracy 0.8586
# Epoch 88 Batch 550 Loss 0.4340 Accuracy 0.8585
# Epoch 88 Batch 600 Loss 0.4348 Accuracy 0.8582
# Epoch 88 Batch 650 Loss 0.4365 Accuracy 0.8576
# Epoch 88 Batch 700 Loss 0.4391 Accuracy 0.8570
# Epoch 88 Batch 750 Loss 0.4397 Accuracy 0.8567
# Epoch 88 Loss 0.4395 Accuracy 0.8567
# Time taken for 1 epoch: 123.46 secs
#
# Epoch 88 Loss 0.2993 Accuracy 0.9045
# Time taken for 1 epoch: 25.11 secs
#
# Epoch 89 Batch 0 Loss 0.5211 Accuracy 0.8249
# Epoch 89 Batch 50 Loss 0.4328 Accuracy 0.8586
# Epoch 89 Batch 100 Loss 0.4337 Accuracy 0.8583
# Epoch 89 Batch 150 Loss 0.4261 Accuracy 0.8607
# Epoch 89 Batch 200 Loss 0.4297 Accuracy 0.8596
# Epoch 89 Batch 250 Loss 0.4317 Accuracy 0.8592
# Epoch 89 Batch 300 Loss 0.4320 Accuracy 0.8589
# Epoch 89 Batch 350 Loss 0.4326 Accuracy 0.8588
# Epoch 89 Batch 400 Loss 0.4341 Accuracy 0.8583
# Epoch 89 Batch 450 Loss 0.4353 Accuracy 0.8578
# Epoch 89 Batch 500 Loss 0.4366 Accuracy 0.8576
# Epoch 89 Batch 550 Loss 0.4362 Accuracy 0.8578
# Epoch 89 Batch 600 Loss 0.4349 Accuracy 0.8581
# Epoch 89 Batch 650 Loss 0.4359 Accuracy 0.8576
# Epoch 89 Batch 700 Loss 0.4371 Accuracy 0.8573
# Epoch 89 Batch 750 Loss 0.4373 Accuracy 0.8573
# Epoch 89 Loss 0.4369 Accuracy 0.8574
# Time taken for 1 epoch: 122.92 secs
#
# Epoch 89 Loss 0.3011 Accuracy 0.9038
# Time taken for 1 epoch: 25.16 secs
#
# Epoch 90 Batch 0 Loss 0.4333 Accuracy 0.8656
# Epoch 90 Batch 50 Loss 0.4406 Accuracy 0.8560
# Epoch 90 Batch 100 Loss 0.4408 Accuracy 0.8560
# Epoch 90 Batch 150 Loss 0.4380 Accuracy 0.8569
# Epoch 90 Batch 200 Loss 0.4371 Accuracy 0.8569
# Epoch 90 Batch 250 Loss 0.4387 Accuracy 0.8565
# Epoch 90 Batch 300 Loss 0.4363 Accuracy 0.8572
# Epoch 90 Batch 350 Loss 0.4345 Accuracy 0.8578
# Epoch 90 Batch 400 Loss 0.4341 Accuracy 0.8580
# Epoch 90 Batch 450 Loss 0.4351 Accuracy 0.8577
# Epoch 90 Batch 500 Loss 0.4345 Accuracy 0.8580
# Epoch 90 Batch 550 Loss 0.4337 Accuracy 0.8582
# Epoch 90 Batch 600 Loss 0.4352 Accuracy 0.8579
# Epoch 90 Batch 650 Loss 0.4355 Accuracy 0.8579
# Epoch 90 Batch 700 Loss 0.4356 Accuracy 0.8578
# Epoch 90 Batch 750 Loss 0.4371 Accuracy 0.8573
# Epoch 90 Loss 0.4368 Accuracy 0.8574
# Time taken for 1 epoch: 125.31 secs
#
# Epoch 90 Loss 0.2979 Accuracy 0.9053
# Time taken for 1 epoch: 25.57 secs
#
# Epoch 91 Batch 0 Loss 0.5098 Accuracy 0.8286
# Epoch 91 Batch 50 Loss 0.4452 Accuracy 0.8542
# Epoch 91 Batch 100 Loss 0.4383 Accuracy 0.8566
# Epoch 91 Batch 150 Loss 0.4345 Accuracy 0.8578
# Epoch 91 Batch 200 Loss 0.4322 Accuracy 0.8586
# Epoch 91 Batch 250 Loss 0.4331 Accuracy 0.8584
# Epoch 91 Batch 300 Loss 0.4311 Accuracy 0.8590
# Epoch 91 Batch 350 Loss 0.4337 Accuracy 0.8583
# Epoch 91 Batch 400 Loss 0.4325 Accuracy 0.8587
# Epoch 91 Batch 450 Loss 0.4327 Accuracy 0.8587
# Epoch 91 Batch 500 Loss 0.4323 Accuracy 0.8588
# Epoch 91 Batch 550 Loss 0.4328 Accuracy 0.8587
# Epoch 91 Batch 600 Loss 0.4333 Accuracy 0.8586
# Epoch 91 Batch 650 Loss 0.4339 Accuracy 0.8584
# Epoch 91 Batch 700 Loss 0.4352 Accuracy 0.8580
# Epoch 91 Batch 750 Loss 0.4361 Accuracy 0.8578
# Epoch 91 Loss 0.4363 Accuracy 0.8578
# Time taken for 1 epoch: 123.34 secs
#
# Epoch 91 Loss 0.2953 Accuracy 0.9065
# Time taken for 1 epoch: 25.22 secs
#
# Epoch 92 Batch 0 Loss 0.3965 Accuracy 0.8689
# Epoch 92 Batch 50 Loss 0.4343 Accuracy 0.8591
# Epoch 92 Batch 100 Loss 0.4293 Accuracy 0.8594
# Epoch 92 Batch 150 Loss 0.4291 Accuracy 0.8592
# Epoch 92 Batch 200 Loss 0.4297 Accuracy 0.8593
# Epoch 92 Batch 250 Loss 0.4295 Accuracy 0.8594
# Epoch 92 Batch 300 Loss 0.4291 Accuracy 0.8595
# Epoch 92 Batch 350 Loss 0.4292 Accuracy 0.8595
# Epoch 92 Batch 400 Loss 0.4316 Accuracy 0.8587
# Epoch 92 Batch 450 Loss 0.4305 Accuracy 0.8589
# Epoch 92 Batch 500 Loss 0.4321 Accuracy 0.8585
# Epoch 92 Batch 550 Loss 0.4320 Accuracy 0.8587
# Epoch 92 Batch 600 Loss 0.4323 Accuracy 0.8586
# Epoch 92 Batch 650 Loss 0.4331 Accuracy 0.8585
# Epoch 92 Batch 700 Loss 0.4331 Accuracy 0.8585
# Epoch 92 Batch 750 Loss 0.4326 Accuracy 0.8586
# Epoch 92 Loss 0.4329 Accuracy 0.8585
# Time taken for 1 epoch: 123.25 secs
#
# Epoch 92 Loss 0.2933 Accuracy 0.9069
# Time taken for 1 epoch: 24.76 secs
#
# Epoch 93 Batch 0 Loss 0.4165 Accuracy 0.8708
# Epoch 93 Batch 50 Loss 0.4287 Accuracy 0.8593
# Epoch 93 Batch 100 Loss 0.4232 Accuracy 0.8607
# Epoch 93 Batch 150 Loss 0.4239 Accuracy 0.8609
# Epoch 93 Batch 200 Loss 0.4232 Accuracy 0.8609
# Epoch 93 Batch 250 Loss 0.4249 Accuracy 0.8603
# Epoch 93 Batch 300 Loss 0.4267 Accuracy 0.8598
# Epoch 93 Batch 350 Loss 0.4282 Accuracy 0.8594
# Epoch 93 Batch 400 Loss 0.4283 Accuracy 0.8594
# Epoch 93 Batch 450 Loss 0.4293 Accuracy 0.8592
# Epoch 93 Batch 500 Loss 0.4316 Accuracy 0.8585
# Epoch 93 Batch 550 Loss 0.4308 Accuracy 0.8587
# Epoch 93 Batch 600 Loss 0.4307 Accuracy 0.8588
# Epoch 93 Batch 650 Loss 0.4318 Accuracy 0.8585
# Epoch 93 Batch 700 Loss 0.4317 Accuracy 0.8586
# Epoch 93 Batch 750 Loss 0.4328 Accuracy 0.8583
# Epoch 93 Loss 0.4327 Accuracy 0.8584
# Time taken for 1 epoch: 124.50 secs
#
# Epoch 93 Loss 0.2914 Accuracy 0.9072
# Time taken for 1 epoch: 25.52 secs
#
# Epoch 94 Batch 0 Loss 0.4506 Accuracy 0.8481
# Epoch 94 Batch 50 Loss 0.4281 Accuracy 0.8599
# Epoch 94 Batch 100 Loss 0.4338 Accuracy 0.8586
# Epoch 94 Batch 150 Loss 0.4305 Accuracy 0.8593
# Epoch 94 Batch 200 Loss 0.4313 Accuracy 0.8590
# Epoch 94 Batch 250 Loss 0.4295 Accuracy 0.8593
# Epoch 94 Batch 300 Loss 0.4274 Accuracy 0.8601
# Epoch 94 Batch 350 Loss 0.4277 Accuracy 0.8600
# Epoch 94 Batch 400 Loss 0.4281 Accuracy 0.8598
# Epoch 94 Batch 450 Loss 0.4292 Accuracy 0.8595
# Epoch 94 Batch 500 Loss 0.4286 Accuracy 0.8596
# Epoch 94 Batch 550 Loss 0.4294 Accuracy 0.8594
# Epoch 94 Batch 600 Loss 0.4292 Accuracy 0.8595
# Epoch 94 Batch 650 Loss 0.4300 Accuracy 0.8592
# Epoch 94 Batch 700 Loss 0.4310 Accuracy 0.8590
# Epoch 94 Batch 750 Loss 0.4308 Accuracy 0.8591
# Epoch 94 Loss 0.4313 Accuracy 0.8589
# Time taken for 1 epoch: 122.69 secs
#
# Epoch 94 Loss 0.2935 Accuracy 0.9061
# Time taken for 1 epoch: 25.31 secs
#
# Epoch 95 Batch 0 Loss 0.4215 Accuracy 0.8683
# Epoch 95 Batch 50 Loss 0.4368 Accuracy 0.8583
# Epoch 95 Batch 100 Loss 0.4306 Accuracy 0.8596
# Epoch 95 Batch 150 Loss 0.4314 Accuracy 0.8591
# Epoch 95 Batch 200 Loss 0.4281 Accuracy 0.8600
# Epoch 95 Batch 250 Loss 0.4289 Accuracy 0.8598
# Epoch 95 Batch 300 Loss 0.4310 Accuracy 0.8592
# Epoch 95 Batch 350 Loss 0.4312 Accuracy 0.8589
# Epoch 95 Batch 400 Loss 0.4318 Accuracy 0.8588
# Epoch 95 Batch 450 Loss 0.4319 Accuracy 0.8587
# Epoch 95 Batch 500 Loss 0.4321 Accuracy 0.8587
# Epoch 95 Batch 550 Loss 0.4315 Accuracy 0.8590
# Epoch 95 Batch 600 Loss 0.4304 Accuracy 0.8592
# Epoch 95 Batch 650 Loss 0.4290 Accuracy 0.8597
# Epoch 95 Batch 700 Loss 0.4286 Accuracy 0.8598
# Epoch 95 Batch 750 Loss 0.4296 Accuracy 0.8595
# Epoch 95 Loss 0.4296 Accuracy 0.8596
# Time taken for 1 epoch: 124.35 secs
#
# Epoch 95 Loss 0.2911 Accuracy 0.9075
# Time taken for 1 epoch: 24.11 secs
#
# Epoch 96 Batch 0 Loss 0.4333 Accuracy 0.8518
# Epoch 96 Batch 50 Loss 0.4335 Accuracy 0.8577
# Epoch 96 Batch 100 Loss 0.4275 Accuracy 0.8594
# Epoch 96 Batch 150 Loss 0.4266 Accuracy 0.8599
# Epoch 96 Batch 200 Loss 0.4252 Accuracy 0.8603
# Epoch 96 Batch 250 Loss 0.4230 Accuracy 0.8609
# Epoch 96 Batch 300 Loss 0.4226 Accuracy 0.8610
# Epoch 96 Batch 350 Loss 0.4221 Accuracy 0.8612
# Epoch 96 Batch 400 Loss 0.4213 Accuracy 0.8614
# Epoch 96 Batch 450 Loss 0.4216 Accuracy 0.8613
# Epoch 96 Batch 500 Loss 0.4220 Accuracy 0.8613
# Epoch 96 Batch 550 Loss 0.4239 Accuracy 0.8609
# Epoch 96 Batch 600 Loss 0.4256 Accuracy 0.8604
# Epoch 96 Batch 650 Loss 0.4261 Accuracy 0.8602
# Epoch 96 Batch 700 Loss 0.4269 Accuracy 0.8599
# Epoch 96 Batch 750 Loss 0.4280 Accuracy 0.8597
# Epoch 96 Loss 0.4281 Accuracy 0.8597
# Time taken for 1 epoch: 123.17 secs
#
# Epoch 96 Loss 0.2864 Accuracy 0.9090
# Time taken for 1 epoch: 24.41 secs
#
# Epoch 97 Batch 0 Loss 0.5365 Accuracy 0.8329
# Epoch 97 Batch 50 Loss 0.4475 Accuracy 0.8540
# Epoch 97 Batch 100 Loss 0.4356 Accuracy 0.8569
# Epoch 97 Batch 150 Loss 0.4287 Accuracy 0.8590
# Epoch 97 Batch 200 Loss 0.4296 Accuracy 0.8589
# Epoch 97 Batch 250 Loss 0.4267 Accuracy 0.8599
# Epoch 97 Batch 300 Loss 0.4261 Accuracy 0.8602
# Epoch 97 Batch 350 Loss 0.4250 Accuracy 0.8607
# Epoch 97 Batch 400 Loss 0.4253 Accuracy 0.8607
# Epoch 97 Batch 450 Loss 0.4254 Accuracy 0.8608
# Epoch 97 Batch 500 Loss 0.4243 Accuracy 0.8610
# Epoch 97 Batch 550 Loss 0.4248 Accuracy 0.8610
# Epoch 97 Batch 600 Loss 0.4245 Accuracy 0.8610
# Epoch 97 Batch 650 Loss 0.4249 Accuracy 0.8610
# Epoch 97 Batch 700 Loss 0.4266 Accuracy 0.8605
# Epoch 97 Batch 750 Loss 0.4272 Accuracy 0.8602
# Epoch 97 Loss 0.4277 Accuracy 0.8601
# Time taken for 1 epoch: 123.27 secs
#
# Epoch 97 Loss 0.2898 Accuracy 0.9079
# Time taken for 1 epoch: 23.98 secs
#
# Epoch 98 Batch 0 Loss 0.4225 Accuracy 0.8563
# Epoch 98 Batch 50 Loss 0.4285 Accuracy 0.8589
# Epoch 98 Batch 100 Loss 0.4253 Accuracy 0.8604
# Epoch 98 Batch 150 Loss 0.4269 Accuracy 0.8600
# Epoch 98 Batch 200 Loss 0.4263 Accuracy 0.8603
# Epoch 98 Batch 250 Loss 0.4253 Accuracy 0.8604
# Epoch 98 Batch 300 Loss 0.4227 Accuracy 0.8611
# Epoch 98 Batch 350 Loss 0.4248 Accuracy 0.8605
# Epoch 98 Batch 400 Loss 0.4248 Accuracy 0.8605
# Epoch 98 Batch 450 Loss 0.4251 Accuracy 0.8605
# Epoch 98 Batch 500 Loss 0.4271 Accuracy 0.8599
# Epoch 98 Batch 550 Loss 0.4273 Accuracy 0.8598
# Epoch 98 Batch 600 Loss 0.4267 Accuracy 0.8600
# Epoch 98 Batch 650 Loss 0.4251 Accuracy 0.8605
# Epoch 98 Batch 700 Loss 0.4251 Accuracy 0.8605
# Epoch 98 Batch 750 Loss 0.4262 Accuracy 0.8603
# Epoch 98 Loss 0.4266 Accuracy 0.8601
# Time taken for 1 epoch: 124.60 secs
#
# Epoch 98 Loss 0.2884 Accuracy 0.9081
# Time taken for 1 epoch: 25.34 secs
#
# Epoch 99 Batch 0 Loss 0.3368 Accuracy 0.8887
# Epoch 99 Batch 50 Loss 0.4239 Accuracy 0.8614
# Epoch 99 Batch 100 Loss 0.4247 Accuracy 0.8617
# Epoch 99 Batch 150 Loss 0.4219 Accuracy 0.8621
# Epoch 99 Batch 200 Loss 0.4242 Accuracy 0.8614
# Epoch 99 Batch 250 Loss 0.4247 Accuracy 0.8610
# Epoch 99 Batch 300 Loss 0.4230 Accuracy 0.8614
# Epoch 99 Batch 350 Loss 0.4233 Accuracy 0.8613
# Epoch 99 Batch 400 Loss 0.4225 Accuracy 0.8617
# Epoch 99 Batch 450 Loss 0.4221 Accuracy 0.8618
# Epoch 99 Batch 500 Loss 0.4228 Accuracy 0.8615
# Epoch 99 Batch 550 Loss 0.4235 Accuracy 0.8613
# Epoch 99 Batch 600 Loss 0.4236 Accuracy 0.8613
# Epoch 99 Batch 650 Loss 0.4240 Accuracy 0.8612
# Epoch 99 Batch 700 Loss 0.4239 Accuracy 0.8613
# Epoch 99 Batch 750 Loss 0.4237 Accuracy 0.8614
# Epoch 99 Loss 0.4233 Accuracy 0.8615
# Time taken for 1 epoch: 122.75 secs
#
# Epoch 99 Loss 0.2828 Accuracy 0.9105
# Time taken for 1 epoch: 24.69 secs
#
# Epoch 100 Batch 0 Loss 0.3684 Accuracy 0.8842
# Epoch 100 Batch 50 Loss 0.4279 Accuracy 0.8609
# Epoch 100 Batch 100 Loss 0.4263 Accuracy 0.8606
# Epoch 100 Batch 150 Loss 0.4236 Accuracy 0.8616
# Epoch 100 Batch 200 Loss 0.4198 Accuracy 0.8627
# Epoch 100 Batch 250 Loss 0.4216 Accuracy 0.8618
# Epoch 100 Batch 300 Loss 0.4210 Accuracy 0.8617
# Epoch 100 Batch 350 Loss 0.4209 Accuracy 0.8616
# Epoch 100 Batch 400 Loss 0.4215 Accuracy 0.8615
# Epoch 100 Batch 450 Loss 0.4216 Accuracy 0.8615
# Epoch 100 Batch 500 Loss 0.4234 Accuracy 0.8610
# Epoch 100 Batch 550 Loss 0.4236 Accuracy 0.8609
# Epoch 100 Batch 600 Loss 0.4246 Accuracy 0.8605
# Epoch 100 Batch 650 Loss 0.4252 Accuracy 0.8604
# Epoch 100 Batch 700 Loss 0.4246 Accuracy 0.8606
# Epoch 100 Batch 750 Loss 0.4237 Accuracy 0.8608
# Epoch 100 Loss 0.4239 Accuracy 0.8608
# Time taken for 1 epoch: 123.86 secs
#
# Epoch 100 Loss 0.2830 Accuracy 0.9103
# Time taken for 1 epoch: 24.04 secs

# %%
print(len(acc_list))
print(len(e_list))
print(len(val_acc_list))
# Out:
# 100
# 100
# 100

# %%
temp = np.array(val_loss_list)
index, = np.where(temp == 0.0000)
  # if (x == 0.0000): print(x.index())
print(index)


temp = np.array(val_acc_list)
index, = np.where(temp == 0.0000)
  # if (x == 0.0000): print(x.index())
print(index)
# Out:
# []
# []

# %%
# plot of accuracy and loss of training data
# e_list =[]
# acc_list = []


xptt_loss = np.array(range(len(loss_list)))
yptt_loss = np.array(loss_list)

plt.plot(xptt_loss, yptt_loss,color = 'r', label = 'Training Loss')
zpoints = np.array(val_loss_list)

plt.plot(xptt_loss, zpoints,color = 'g', label = 'Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid()
plt.legend()
plt.show()

# %%
xp_ep= np.array(range(len(acc_list)))
yp_tacc = np.array(acc_list)*100

plt.plot(xp_ep, yp_tacc,color = 'r',label = ' Validation Accuracy')
zp_vacc = np.array(val_acc_list)*100

plt.plot(xp_ep, zp_vacc,color = 'g',label = 'Training  Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()
plt.show()

# %%
# @keras.utils.generic_utils.register_keras_serializable
class Translator(tf.Module):
  # Translator.__name__ = 'Translator'
  def __init__(self, tokenizers, transformer):
    self.tokenizers = tokenizers
    self.transformer = transformer

  def __call__(self, sentence, max_length=MAX_TOKENS):
    # input sentence is problem statement, hence adding the start and end token
    assert isinstance(sentence, tf.Tensor)
    if len(sentence.shape) == 0:
      sentence = sentence[tf.newaxis]

    sentence = self.tokenizers.prob.tokenize(sentence).to_tensor()

    encoder_input = sentence

    # As the output language is cpp program, initialize the output with the
    # english start token.
    start_end = self.tokenizers.sol.tokenize([''])[0]
    start = start_end[0][tf.newaxis]
    end = start_end[1][tf.newaxis]

    # `tf.TensorArray` is required here (instead of a python list) so that the
    # dynamic-loop can be traced by `tf.function`.
    output_array = tf.TensorArray(dtype=tf.int64, size=0, dynamic_size=True)
    output_array = output_array.write(0, start)

    for i in tf.range(max_length):
      output = tf.transpose(output_array.stack())
      predictions, _ = self.transformer([encoder_input, output], training=False)

      # select the last token from the seq_len dimension
      predictions = predictions[:, -1:, :]  # (batch_size, 1, vocab_size)

      predicted_id = tf.argmax(predictions, axis=-1)

      # concatentate the predicted_id to the output which is given to the decoder
      # as its input.
      output_array = output_array.write(i+1, predicted_id[0])

      if predicted_id == end:
        break

    output = tf.transpose(output_array.stack())
    # output.shape (1, tokens)
    text = tokenizers.sol.detokenize(output)[0]  # shape: ()

    tokens = tokenizers.sol.lookup(output)[0]

    # `tf.function` prevents us from using the attention_weights that were
    # calculated on the last iteration of the loop. So recalculate them outside
    # the loop.
    _, attention_weights = self.transformer([encoder_input, output[:,:-1]], training=False)

    return text, tokens, attention_weights

# %%
# with custom_object_scope({'my_t': my_t}):
translator = Translator(tokenizers, transformer)

# %%
def print_translation(sentence, tokens, ground_truth):
  print(f'{"Input:":15s}: {sentence}')

  print("\n\n")
  print(f'{"Prediction":15s}: {tokens.numpy().decode("utf-8")}')
  print("\n\n")
  print(f'{"Ground truth":15s}: {ground_truth}')
  
  print("\n\n")

# %%
sentence = 'create map iterator it from string to integer    create integer n    read n    read character    for i = 0 to n exclusive    create sting str    read line from cin to str    set m[str] to 1    create integer ans with ans = 0    for it = beginning of m to it is not end of m, incrementing it, increment ans    print ans print newline    '
ground_truth = 'map<string, int>::iterator it;    int main() {    int n;    cin >> n;    getchar();    for (int i = 0; i < n; i++) {    string str;    getline(cin, str);    m[str] = 1;    }    int ans = 0;    for (it = m.begin(); it != m.end(); it++) { ans++; }    cout << ans << endl;    }    '

translated_text, translated_tokens, attention_weights = translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : create map iterator it from string to integer    create integer n    read n    read character    for i = 0 to n exclusive    create sting str    read line from cin to str    set m[str] to 1    create integer ans with ans = 0    for it = beginning of m to it is not end of m, incrementing it, increment ans    print ans print newline
#
#
#
# Prediction     : map < string , int > : : iterator it ; int main ( ) { int n ; cin > > n ; getchar ( ) ; for ( int i = 0 ; i < n ; i + + ) { string str ; getline ( cin , str ) ; m [ str ] + + ; } int ans = 0 ; for ( it = m . begin ( ) ; it ! = m . end ( ) ; it + + ) { ans + + ; } cout < < ans < < endl ; return 0 ; }
#
#
#
# Ground truth   : map<string, int>::iterator it;    int main() {    int n;    cin >> n;    getchar();    for (int i = 0; i < n; i++) {    string str;    getline(cin, str);    m[str] = 1;    }    int ans = 0;    for (it = m.begin(); it != m.end(); it++) { ans++; }    cout << ans << endl;    }

# %%
sentence = 'let t an int      read t      while postdecrement t      let s a string      read s      if size of s at most 10      print s      continue      otherwise      print s[0], followed by size of s less 2, followed by s[size of s less 1]      '
ground_truth = 'int n, m, i, j, pos = 0;      cin >> n >> m;      int c[n], a[m];      for (i = 0; i < n; i++) { cin >> c[i]; }      for (j = 0; j < m; j++) { cin >> a[j]; }      for (i = 0; i < n; i++) {      if (pos < m) {      if (a[pos] >= c[i]) {      pos = pos + 1;      } else {      continue;      }      }      }      cout << pos << endl;      return 0;      }      '

translated_text, translated_tokens, attention_weights = translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : let t an int      read t      while postdecrement t      let s a string      read s      if size of s at most 10      print s      continue      otherwise      print s[0], followed by size of s less 2, followed by s[size of s less 1]
#
#
#
# Prediction     : int t ; cin > > t ; while ( t - - ) { string s ; cin > > s ; if ( ( s . size ( ) ) < = 10 ) { cout < < s [ 0 ] < < s . size ( ) - 2 < < s [ s . size ( ) - 1 ] < < endl ; continue ; } else { cout < < s < < endl ; } } return 0 ; }
#
#
#
# Ground truth   : int n, m, i, j, pos = 0;      cin >> n >> m;      int c[n], a[m];      for (i = 0; i < n; i++) { cin >> c[i]; }      for (j = 0; j < m; j++) { cin >> a[j]; }      for (i = 0; i < n; i++) {      if (pos < m) {      if (a[pos] >= c[i]) {      pos = pos + 1;      } else {      continue;      }      }      }      cout << pos << endl;      return 0;      }

# %%
sentence = 'declare integers num1, num2     input num1,num2      product = num1*num2     print product'
ground_truth = 'int main()   {int num1,num2;   cin>>num1>>num2;   product = num1*num2  ;   cout<<product;   return 0;}'

translated_text, translated_tokens, attention_weights = translator( tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : declare integers num1, num2     input num1,num2      product = num1*num2     print product
#
#
#
# Prediction     : double ats , reinf , numofinf ; cin > > current > > numofinf ; int aes = current year * ( nsinf + 1 ) ; cout < < a < < endl ; return 0 ; }
#
#
#
# Ground truth   : int main()   {int num1,num2;   cin>>num1>>num2;   product = num1*num2  ;   cout<<product;   return 0;}

# %%
sentence = 'declare integers num1    take input num1, num2    print num1+ num2'
ground_truth = 'int main() { int num1;    cin>>num1>>num2 ;   cout<<num1+num2;    return 0;}'

translated_text, translated_tokens, attention_weights = translator( tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : declare integers num1    take input num1, num2    print num1+ num2
#
#
#
# Prediction     : int num1 , num2 ; cin > > num1 > > num2 ; num1 = num1 + num2 ; cout < < num1 < < endl ; return 0 ; }
#
#
#
# Ground truth   : int main() { int num1;    cin>>num1>>num2 ;   cout<<num1+num2;    return 0;}

# %%
sentence = 'declare integer a   input a   print a '
ground_truth = 'int main(){ int a;  cin>> a;  cout<<a;   return 0;}'

translated_text, translated_tokens, attention_weights = translator( tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : declare integer a   input a   print a
#
#
#
# Prediction     : int a ; cin > > a ; cout < < a < < endl ; return 0 ; }
#
#
#
# Ground truth   : int main(){ int a;  cin>> a;  cout<<a;   return 0;}

# %%
def plot_attention_head(in_tokens, translated_tokens, attention):
  # The plot is of the attention when a token was generated.
  # The model didn't generate `<START>` in the output. Skip it.
  translated_tokens = translated_tokens[1:]

  ax = plt.gca()
  ax.matshow(attention)
  ax.set_xticks(range(len(in_tokens)))
  ax.set_yticks(range(len(translated_tokens)))

  labels = [label.decode('utf-8') for label in in_tokens.numpy()]
  ax.set_xticklabels(
      labels, rotation=90)

  labels = [label.decode('utf-8') for label in translated_tokens.numpy()]
  ax.set_yticklabels(labels)

# %%
head = 0
# shape: (batch=1, num_heads, seq_len_q, seq_len_k)
attention_heads = tf.squeeze(
  attention_weights['decoder_layer4_block2'], 0)
attention = attention_heads[head]
attention.shape
# Out:
# TensorShape([21, 9])

# %%
in_tokens = tf.convert_to_tensor([sentence])
in_tokens = tokenizers.prob.tokenize(in_tokens).to_tensor()
in_tokens = tokenizers.prob.lookup(in_tokens)[0]
in_tokens
# Out:
# <tf.Tensor: shape=(9,), dtype=string, numpy=
# array([b'[START]', b'declare', b'integer', b'a', b'input', b'a', b'print',
#        b'a', b'[END]'], dtype=object)>

# %%
translated_tokens
# Out:
# <tf.Tensor: shape=(22,), dtype=string, numpy=
# array([b'[START]', b'int', b'a', b';', b'cin', b'>', b'>', b'a', b';',
#        b'cout', b'<', b'<', b'a', b'<', b'<', b'endl', b';', b'return',
#        b'0', b';', b'}', b'[END]'], dtype=object)>

# %%
plot_attention_head(in_tokens, translated_tokens, attention)

# %%
def plot_attention_weights(sentence, translated_tokens, attention_heads):
  in_tokens = tf.convert_to_tensor([sentence])
  in_tokens = tokenizers.prob.tokenize(in_tokens).to_tensor()
  in_tokens = tokenizers.prob.lookup(in_tokens)[0]
  in_tokens

  fig = plt.figure(figsize=(16, 8))

  for h, head in enumerate(attention_heads):
    ax = fig.add_subplot(2, 4, h+1)

    plot_attention_head(in_tokens, translated_tokens, head)

    ax.set_xlabel(f'Head {h+1}')

  plt.tight_layout()
  plt.show()

# %%
plot_attention_weights(sentence, translated_tokens,
                       attention_weights['decoder_layer4_block2'][0])

# %%
class ExportTranslator(tf.Module):
#   ExportTranslator.__name__ = 'ExportTranslator'
  def __init__(self, translator):
    self.translator = translator

  @tf.function(input_signature=[tf.TensorSpec(shape=[], dtype=tf.string)])
  def __call__(self, sentence):
    (result,
     tokens,
     attention_weights) = self.translator(sentence, max_length=MAX_TOKENS)

    return result

# %%
translator = ExportTranslator(translator)

# %%
translator('declare int a').numpy()
# Out:
# b'int a ; int main ( ) { int a ; cin > > a ; cout < < ( a ) < < endl ; return 0 ; }'

# %%
tf.saved_model.save(translator, export_dir='drive/MyDrive/MajorProjectPseudoCodeCpp/PseudocodeModel')
# Out:
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_8_layer_call_fn, dropout_8_layer_call_and_return_conditional_losses, embedding_1_layer_call_fn while saving (showing 5 of 224). These functions will not be directly callable after loading.

# %%
model_t = tf.saved_model.load('drive/MyDrive/MajorProjectPseudoCodeCpp/PseudocodeModel')

# %%
model_t('''
declare integer variable A, B, C,n
take input n
Set A = 0, B = 0
DISPLAY A, B
for n times
  C = A + B
  DISPLAY C
  Set A = B, B = C''').numpy()
# Out:
# b'int n , a , b , c = 0 ; cin > > n ; while ( n - - ) { cin > > a > > b ; c = a + b ; } cout < < c < < " \\ n " ; return 0 ; }'

# %%
model_t('declare integer a   input a   print a ').numpy()
# Out:
# b'int a ; cin > > a ; cout < < a < < endl ; return 0 ; }'
